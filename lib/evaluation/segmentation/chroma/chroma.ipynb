# %% [markdown]
# # Parsing Evaluation with Chroma

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

from chunking_evaluation import GeneralEvaluation
from dotenv import load_dotenv
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction

from lib.evaluation.segmentation.chroma.chroma_adapter import ChromaChunker
from lib.segmentation.methods.implementations.fixed_sized import FixedSizeChunker
from lib.segmentation.methods.implementations.recursive import RecursiveChunker
from lib.segmentation.methods.implementations.hierarchical import HierarchicalChunker
from lib.segmentation.methods.implementations.semantic import SemanticChunker
from lib.parsing.methods.parsers import Parsers
from lib.utils.export_table import export_table_to_latex
# Out:
# 2026-02-12 16:27:48,291 - INFO : Use pytorch device_name: mps
# 2026-02-12 16:27:48,291 - INFO : Load pretrained SentenceTransformer: all-MiniLM-L6-v2

# %%
chunkers = [
    FixedSizeChunker(max_tokens=128, overlap=0),
    # FixedSizeChunker(max_tokens=128, overlap=50),
    # FixedSizeChunker(max_tokens=256, overlap=0),
    # FixedSizeChunker(max_tokens=256, overlap=100),
    # FixedSizeChunker(max_tokens=512, overlap=0),
    # FixedSizeChunker(max_tokens=512, overlap=200),
    # FixedSizeChunker(max_tokens=1028, overlap=0),
    # FixedSizeChunker(max_tokens=1028, overlap=300),
    RecursiveChunker(max_tokens=128, overlap=0),
    # RecursiveChunker(max_tokens=128, overlap=50),
    # RecursiveChunker(max_tokens=256, overlap=0),
    # RecursiveChunker(max_tokens=256, overlap=100),
    # RecursiveChunker(max_tokens=512, overlap=0),
    # RecursiveChunker(max_tokens=512, overlap=200),
    # RecursiveChunker(max_tokens=1028, overlap=0),
    # RecursiveChunker(max_tokens=1028, overlap=300),
    SemanticChunker(max_tokens=128, similarity_threshold=95, min_tokens=64),
    # SemanticChunker(max_tokens=128, similarity_threshold=85, min_tokens=64),
    # SemanticChunker(max_tokens=256, similarity_threshold=95, min_tokens=128),
    # SemanticChunker(max_tokens=256, similarity_threshold=85, min_tokens=128),
    # SemanticChunker(max_tokens=512, similarity_threshold=85, min_tokens=256),
    # SemanticChunker(max_tokens=512, similarity_threshold=85, min_tokens=256),
    # SemanticChunker(max_tokens=1024, similarity_threshold=85, min_tokens=512),
    # SemanticChunker(max_tokens=1024, similarity_threshold=85, min_tokens=512),
    HierarchicalChunker(max_tokens=128, max_parent_token_ratio=0.4),
    # HierarchicalChunker(max_tokens=256, max_parent_token_ratio=0.4),
    # HierarchicalChunker(max_tokens=512, max_parent_token_ratio=0.4),
    # HierarchicalChunker(max_tokens=1024, max_parent_token_ratio=0.4),
]

# %%
chunkers = [
    ChromaChunker(c) for c in chunkers
]

# %%
# Make sure "OPENAI_API_KEY" is set in a .env file
load_dotenv()
embedding_function = OpenAIEmbeddingFunction(model_name="text-embedding-3-small")

# %% [markdown]
# ## General Evaluation (predefined data sets)

# %%
evaluation = GeneralEvaluation()

results = []
pubmed_results = []

for chunker in chunkers:
    c_info = chunker.get_info()

    c_res = evaluation.run(chunker, embedding_function)
    pubmed_scores = c_res["corpora_scores"]["pubmed"]
    del c_res["corpora_scores"]

    # Add method info to all-corpus-mean scores
    c_res.update(c_info)
    results.append(c_res)

    # Get data for pubmed only
    c_row = {}
    for metric, scores in pubmed_scores.items():
        metric_name = metric.replace("_scores", "")
        c_row[f"{metric_name}_mean"] = np.mean(scores)
        c_row[f"{metric_name}_std"] = np.std(scores)

    c_row.update(c_info)
    pubmed_results.append(c_row)
# Out:
# 2026-02-12 19:33:11,243 - INFO : Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2026-02-12 19:33:14,138 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:15,332 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:18,406 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:19,532 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:20,761 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:21,988 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:23,762 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:25,162 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:26,292 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:26,405 - INFO : Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2026-02-12 19:33:29,364 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:30,359 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:31,512 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:32,535 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:33,562 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:35,098 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:36,227 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:37,451 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:39,088 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:40,421 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:41,450 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:33:42,570 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:10,509 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:11,554 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:12,789 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:13,912 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:15,245 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:16,676 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:17,609 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:18,724 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:19,680 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:20,776 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:21,794 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:23,433 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:27,016 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:28,143 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:29,272 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:30,297 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:31,524 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:32,650 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:33,946 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:35,569 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:36,709 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:37,756 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:38,998 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:35:39,919 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
pd.DataFrame(results)
# Out:
#    iou_mean   iou_std  recall_mean  recall_std  precision_omega_mean  \
# 0  0.071491  0.055421     0.816822    0.336828              0.278425
# 1  0.090608  0.073304     0.822958    0.345349              0.395015
# 2  0.090176  0.074340     0.799091    0.364234              0.395383
# 3  0.091240  0.074133     0.812893    0.353815              0.400717
#
#    precision_omega_std  precision_mean  precision_std        Method     Param  \
# 0             0.142281        0.072443       0.056761    Fixed-Size     $O=0$
# 1             0.207236        0.091829       0.075006     Recursive     $O=0$
# 2             0.212419        0.091500       0.076112      Semantic    $Q=95$
# 3             0.210302        0.092579       0.075877  Hierarchical  $B_h=51$
#
#      N
# 0  128
# 1  128
# 2  128
# 3  128

# %%
pd.DataFrame(pubmed_results)
# Out:
#    precision_omega_mean  precision_omega_std  iou_mean   iou_std  recall_mean  \
# 0              0.332326             0.147490  0.077619  0.061587     0.694596
# 1              0.473584             0.220278  0.097231  0.090001     0.658639
# 2              0.478609             0.220840  0.098755  0.091438     0.657864
# 3              0.478852             0.220908  0.098653  0.091321     0.654723
#
#    recall_std  precision_mean  precision_std        Method     Param    N
# 0    0.393006        0.079566       0.062785    Fixed-Size     $O=0$  128
# 1    0.426371        0.100027       0.092139     Recursive     $O=0$  128
# 2    0.426532        0.101576       0.093530      Semantic    $Q=95$  128
# 3    0.426583        0.101600       0.093345  Hierarchical  $B_h=51$  128

# %% [markdown]
# ## Synthetic Evaluation

# %%
from lib.evaluation.segmentation.chroma.chroma_setup import setup_synthetic_evaluation

synth_eval = setup_synthetic_evaluation(
    Parsers.DOCLING,
    "chroma_eval",
    parse_exist_ok=True,
    query_exist_ok=True
)
# Out:
# 2026-02-12 16:27:57,952 - INFO : Chroma document corpus exists at /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/chroma/docling/chroma_eval.txt.Skipping generation.
# 2026-02-12 16:27:57,962 - INFO : Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2026-02-12 16:27:58,034 - INFO : Finished creating synthetic evaluation.

# %%
results = []

for chunker in chunkers:
    c_info = chunker.get_info()
    print(c_info)

    c_res = synth_eval.run(chunker, embedding_function, retrieve=-1)
    del c_res["corpora_scores"]

    c_res.update(c_info)
    results.append(c_res)
# Out:
# {'Method': 'Fixed-Size', 'Param': '$O=0$', 'N': 128}
# 2026-02-12 19:10:04,801 - INFO : Chunking 018-029OLp_S3_Hodgkin-Lymphom_Erwachsene_Diagnostik_Therapie_Nachsorge_2022-04 using FIXED_SIZE...
# 2026-02-12 19:10:05,082 - INFO : Chunking 015-076p1_S2k_Frueher-Schwangerschaftsverlust-im-1-Trimenon_2025-06 using FIXED_SIZE...
# 2026-02-12 19:10:05,112 - INFO : Chunking 017-064p_S3_Chronischer_Tinnitus_2021-09 using FIXED_SIZE...
# 2026-02-12 19:10:05,154 - INFO : Chunking 018-032OLp_S3_Chronisch-lymphatische-Leukaemie_2021-07 using FIXED_SIZE...
# 2026-02-12 19:10:05,444 - INFO : Chunking 015-081p_S3_Adipositas-Schwangerschaft_2020_02 using FIXED_SIZE...
# 2026-02-12 19:10:05,478 - INFO : Chunking 015-076p2_S2k_Frueher-Schwangerschaftsverlust-im-1-Trimenon_2025-06 using FIXED_SIZE...
# 2026-02-12 19:10:08,019 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:10:11,706 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:10:14,882 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:10:16,006 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:10:16,924 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:10:17,476 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:16:42,448 - INFO : Chunking 018-029OLp_S3_Hodgkin-Lymphom_Erwachsene_Diagnostik_Therapie_Nachsorge_2022-04 using FIXED_SIZE...
# 2026-02-12 19:16:42,896 - INFO : Chunking 015-076p1_S2k_Frueher-Schwangerschaftsverlust-im-1-Trimenon_2025-06 using FIXED_SIZE...
# 2026-02-12 19:16:42,907 - INFO : Chunking 017-064p_S3_Chronischer_Tinnitus_2021-09 using FIXED_SIZE...
# 2026-02-12 19:16:42,930 - INFO : Chunking 018-032OLp_S3_Chronisch-lymphatische-Leukaemie_2021-07 using FIXED_SIZE...
# 2026-02-12 19:16:43,043 - INFO : Chunking 015-081p_S3_Adipositas-Schwangerschaft_2020_02 using FIXED_SIZE...
# 2026-02-12 19:16:43,057 - INFO : Chunking 015-076p2_S2k_Frueher-Schwangerschaftsverlust-im-1-Trimenon_2025-06 using FIXED_SIZE...
# 2026-02-12 19:16:44,388 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:16:45,733 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:16:47,884 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:16:50,752 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:16:53,466 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 19:19:13,342 - INFO : Chunking 018-029OLp_S3_Hodgkin-Lymphom_Erwachsene_Diagnostik_Therapie_Nachsorge_2022-04 using FIXED_SIZE...
# 2026-02-12 19:19:13,456 - INFO : Chunking 015-076p1_S2k_Frueher-Schwangerschaftsverlust-im-1-Trimenon_2025-06 using FIXED_SIZE...
# 2026-02-12 19:19:13,467 - INFO : Chunking 017-064p_S3_Chronischer_Tinnitus_2021-09 using FIXED_SIZE...
# 2026-02-12 19:19:13,495 - INFO : Chunking 018-032OLp_S3_Chronisch-lymphatische-Leukaemie_2021-07 using FIXED_SIZE...
# 2026-02-12 19:19:13,608 - INFO : Chunking 015-081p_S3_Adipositas-Schwangerschaft_2020_02 using FIXED_SIZE...
# 2026-02-12 19:19:13,623 - INFO : Chunking 015-076p2_S2k_Frueher-Schwangerschaftsverlust-im-1-Trimenon_2025-06 using FIXED_SIZE...
# {'Method': 'Recursive', 'Param': '$O=0$', 'N': 128}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 5
#       3 for chunker in chunkers:
#       4     c_info = chunker.get_info()
# ----> 5     print(c_info)
#       7     c_res = synth_eval.run(chunker, embedding_function)
#       8     del c_res["corpora_scores"]
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3056, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3052 """Write data to both the original destination and the capture dictionary."""
#    3053 result = original_write(data, *args, **kwargs)
#    3054 if any(
#    3055     [
# -> 3056         self.display_pub.is_publishing,
#    3057         self.displayhook.is_active,
#    3058         self.showing_traceback,
#    3059     ]
#    3060 ):
#    3061     return result
#    3062 if not data:
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/IPython/core/displaypub.py:172, in DisplayPublisher.is_publishing(self)
#     169         print(data["text/plain"])
#     170     self._is_publishing = False
# --> 172 @property
#     173 def is_publishing(self):
#     174     return self._is_publishing
#     176 def clear_output(self, wait=False):
#
# KeyboardInterrupt:

# %%
res_df = pd.DataFrame(results)
res_df.set_index(["Method", "Param"], inplace=True)
res_df.index.names = [None, None]
res_df
# Out:
#                        iou_mean   iou_std  recall_mean  recall_std  \
# Fixed-Size   $O=0$     0.113335  0.084413     0.545414    0.351068
# Recursive    $O=0$     0.133429  0.092111     0.515405    0.337660
# Semantic     $Q=95$    0.137409  0.098823     0.494041    0.358025
# Hierarchical $B_h=51$  0.162450  0.139190     0.506803    0.343865
#
#                        precision_omega_mean  precision_omega_std  \
# Fixed-Size   $O=0$                 0.403693             0.158890
# Recursive    $O=0$                 0.443631             0.175662
# Semantic     $Q=95$                0.443980             0.173321
# Hierarchical $B_h=51$              0.411051             0.173514
#
#                        precision_mean  precision_std    N
# Fixed-Size   $O=0$           0.126384       0.098616  128
# Recursive    $O=0$           0.158613       0.111838  128
# Semantic     $Q=95$          0.164830       0.117221  128
# Hierarchical $B_h=51$        0.191374       0.160153  128

# %%
def combine_cols(df, metric_name: str):
    mean_col = f"{metric_name}_mean"
    std_col = f"{metric_name}_std"

    sorted_mean = df[mean_col].round(2).unique()
    sorted_mean.sort()

    max_val = sorted_mean[-1]
    second_val = sorted_mean[-2]

    def highlight_str(row):
        mean = round(row[mean_col], 2)
        std = round(row[std_col], 2)
        cell = fr"{mean:.2f} \pm {std:.2f}"

        if mean == max_val:
            return fr"$\mathbf{{{cell}}}$"
        elif mean == second_val:
            return fr"\underline{{${cell}$}}"
        else:
            return f"${cell}$"

    df[metric_name.capitalize()] = df.apply(highlight_str, axis=1)

# %%
combined_df = res_df.copy()

combine_cols(combined_df, "iou")
combine_cols(combined_df, "precision")
combine_cols(combined_df, "recall")
combine_cols(combined_df, "precision_omega")

combined_df = combined_df[["N", "Iou", "Recall", "Precision", "Precision_omega"]]
combined_df = combined_df.rename(columns={
    "Iou": "IoU",
    "Precision_omega": r"$\text{Precision}_\Omega$"
})

export_table_to_latex(
    combined_df,
    name="chroma_results",
    column_format="llccccc",
    escape_latex=False,
    highlight_mode=None,
)
# Out:
# 2026-02-12 17:17:49,006 - INFO : Saved table content to: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/thesis/figures/tables/chroma_results.tex
