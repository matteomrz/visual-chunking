# %% [markdown]
# # Parsing Evaluation with Chroma

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

from chunking_evaluation import GeneralEvaluation
from dotenv import load_dotenv
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction

from lib.evaluation.segmentation.chroma.chroma_adapter import ChromaChunker
from lib.segmentation.methods.implementations.fixed_sized import FixedSizeChunker
from lib.segmentation.methods.implementations.recursive import RecursiveChunker
from lib.segmentation.methods.implementations.hierarchical import HierarchicalChunker
from lib.segmentation.methods.implementations.semantic import SemanticChunker
from lib.parsing.methods.parsers import Parsers
from lib.utils.export_table import export_table_to_latex
# Out:
# /Users/matteo/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/chunking_evaluation/chunking/llm_semantic_chunker.py:100: SyntaxWarning: invalid escape sequence '\T'
#   "Respond only with the IDs of the chunks where you believe a split should occur. YOU MUST RESPOND WITH AT LEAST ONE SPLIT. THESE SPLITS MUST BE IN ASCENDING ORDER AND EQUAL OR LARGER THAN: " + str(current_chunk)+"." + (f"\n\The previous response of {invalid_response} was invalid. DO NOT REPEAT THIS ARRAY OF NUMBERS. Please try again." if invalid_response else "")
# 2026-02-14 22:38:35,948 - INFO : Use pytorch device_name: mps
# 2026-02-14 22:38:35,948 - INFO : Load pretrained SentenceTransformer: all-MiniLM-L6-v2

# %%
chunkers = [
    FixedSizeChunker(max_tokens=128, overlap=0),
    # FixedSizeChunker(max_tokens=128, overlap=50),
    # FixedSizeChunker(max_tokens=256, overlap=0),
    # FixedSizeChunker(max_tokens=256, overlap=100),
    # FixedSizeChunker(max_tokens=512, overlap=0),
    # FixedSizeChunker(max_tokens=512, overlap=200),
    # FixedSizeChunker(max_tokens=1028, overlap=0),
    # FixedSizeChunker(max_tokens=1028, overlap=300),
    RecursiveChunker(max_tokens=128, overlap=0),
    # RecursiveChunker(max_tokens=128, overlap=50),
    # RecursiveChunker(max_tokens=256, overlap=0),
    # RecursiveChunker(max_tokens=256, overlap=100),
    # RecursiveChunker(max_tokens=512, overlap=0),
    # RecursiveChunker(max_tokens=512, overlap=200),
    # RecursiveChunker(max_tokens=1028, overlap=0),
    # RecursiveChunker(max_tokens=1028, overlap=300),
    SemanticChunker(max_tokens=128, similarity_threshold=95, min_tokens=64),
    # SemanticChunker(max_tokens=128, similarity_threshold=85, min_tokens=64),
    # SemanticChunker(max_tokens=256, similarity_threshold=95, min_tokens=128),
    # SemanticChunker(max_tokens=256, similarity_threshold=85, min_tokens=128),
    # SemanticChunker(max_tokens=512, similarity_threshold=85, min_tokens=256),
    # SemanticChunker(max_tokens=512, similarity_threshold=85, min_tokens=256),
    # SemanticChunker(max_tokens=1024, similarity_threshold=85, min_tokens=512),
    # SemanticChunker(max_tokens=1024, similarity_threshold=85, min_tokens=512),
    HierarchicalChunker(max_tokens=128, max_parent_token_ratio=0.4),
    # HierarchicalChunker(max_tokens=256, max_parent_token_ratio=0.4),
    # HierarchicalChunker(max_tokens=512, max_parent_token_ratio=0.4),
    # HierarchicalChunker(max_tokens=1024, max_parent_token_ratio=0.4),
]

# %%
chunkers = [
    ChromaChunker(c) for c in chunkers
]

# %%
# Make sure "OPENAI_API_KEY" is set in a .env file
load_dotenv()
embedding_function = OpenAIEmbeddingFunction(model_name="text-embedding-3-small")

# %% [markdown]
# ## General Evaluation (predefined data sets)

# %%
evaluation = GeneralEvaluation()

results = []
pubmed_results = []

for chunker in chunkers:
    c_info = chunker.get_info()

    c_res = evaluation.run(chunker, embedding_function)
    pubmed_scores = c_res["corpora_scores"]["pubmed"]
    del c_res["corpora_scores"]

    # Add method info to all-corpus-mean scores
    c_res.update(c_info)
    results.append(c_res)

    # Get data for pubmed only
    c_row = {}
    for metric, scores in pubmed_scores.items():
        metric_name = metric.replace("_scores", "")
        c_row[f"{metric_name}_mean"] = np.mean(scores)
        c_row[f"{metric_name}_std"] = np.std(scores)

    c_row.update(c_info)
    pubmed_results.append(c_row)

# %%
pd.DataFrame(results)

# %%
pd.DataFrame(pubmed_results)

# %% [markdown]
# ## Synthetic Evaluation

# %%
from lib.evaluation.segmentation.chroma.chroma_setup import setup_evaluation_from_medical_qas

synth_eval = setup_evaluation_from_medical_qas(
    Parsers.DOCLING,
    "awmf",
    parse_exist_ok=True,
    question_exist_ok=True
)
# Out:
# 2026-02-14 22:45:52,036 - INFO : Parsing 187-050 using DOCLING...
# 2026-02-14 22:45:52,037 - INFO : detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-02-14 22:45:52,095 - INFO : Going to convert document batch...
# 2026-02-14 22:45:52,096 - INFO : Initializing pipeline for StandardPdfPipeline with options hash 2b180c1bcae7ecc36ce1042af7f80137
# 2026-02-14 22:45:52,122 - INFO : Loading plugin 'docling_defaults'
# 2026-02-14 22:45:52,124 - INFO : Registered picture descriptions: ['picture_description_vlm_engine', 'vlm', 'api']
# 2026-02-14 22:45:52,130 - INFO : Loading plugin 'docling_defaults'
# 2026-02-14 22:45:52,137 - INFO : Registered ocr engines: ['auto', 'easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2026-02-14 22:45:52,589 - INFO : Auto OCR model selected ocrmac.
# 2026-02-14 22:45:52,594 - INFO : Loading plugin 'docling_defaults'
# 2026-02-14 22:45:52,598 - INFO : Registered layout engines: ['layout_object_detection', 'docling_layout_default', 'docling_experimental_table_crops_layout']
# 2026-02-14 22:45:52,607 - INFO : Accelerator device: 'mps'
# 2026-02-14 22:45:53,619 - INFO : Loading plugin 'docling_defaults'
# 2026-02-14 22:45:53,623 - INFO : Registered table structure engines: ['docling_tableformer']
# 2026-02-14 22:45:53,806 - INFO : Accelerator device: 'mps'
# 2026-02-14 22:45:54,386 - INFO : Processing document 187-050.pdf
# 2026-02-14 22:47:54,635 - INFO : Finished converting document 187-050.pdf in 122.60 sec.
# 2026-02-14 22:47:54,660 - INFO : Parsing completed.
# 2026-02-14 22:47:54,660 - INFO : Transforming output to ParsingResult...
# 2026-02-14 22:47:54,926 - INFO : Transformation completed
# 2026-02-14 22:47:54,974 - INFO : Parsing Time: 122.62s
# 2026-02-14 22:47:55,006 - INFO : Adding span-level bounding boxes for: 187-050
# 2026-02-14 22:47:59,865 - INFO : Markdown output saved at: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/markdown/docling/awmf/187-050.md
# 2026-02-14 22:48:00,020 - INFO : JSON output saved at: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/bounding-boxes/docling/awmf/187-050.json
# 2026-02-14 22:48:00,026 - INFO : Parsing 045-024 using DOCLING...
# 2026-02-14 22:48:00,029 - INFO : detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-02-14 22:48:00,035 - INFO : Going to convert document batch...
# 2026-02-14 22:48:00,036 - INFO : Initializing pipeline for StandardPdfPipeline with options hash c70793f6e41efb6c4a787c8c34797ff6
# 2026-02-14 22:48:00,036 - INFO : Auto OCR model selected ocrmac.
# 2026-02-14 22:48:00,036 - INFO : Accelerator device: 'mps'
# 2026-02-14 22:48:00,955 - INFO : Accelerator device: 'mps'
# 2026-02-14 22:48:01,584 - INFO : Processing document 045-024.pdf
# 2026-02-14 22:48:54,642 - INFO : Finished converting document 045-024.pdf in 54.61 sec.
# 2026-02-14 22:48:54,658 - INFO : Parsing completed.
# 2026-02-14 22:48:54,659 - INFO : Transforming output to ParsingResult...
# 2026-02-14 22:48:54,662 - WARNING : Missing mapping for label 'UNSPECIFIED' in DOCLING.
# 2026-02-14 22:48:54,724 - INFO : Transformation completed
# 2026-02-14 22:48:54,726 - INFO : Parsing Time: 54.63s
# 2026-02-14 22:48:54,728 - INFO : Adding span-level bounding boxes for: 045-024
# 2026-02-14 22:48:55,846 - INFO : Markdown output saved at: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/markdown/docling/awmf/045-024.md
# 2026-02-14 22:48:55,897 - INFO : JSON output saved at: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/bounding-boxes/docling/awmf/045-024.json
# 2026-02-14 22:48:55,903 - INFO : Parsing 183-001 using DOCLING...
# 2026-02-14 22:48:55,904 - INFO : detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-02-14 22:48:55,915 - INFO : Going to convert document batch...
# 2026-02-14 22:48:55,916 - INFO : Processing document 183-001.pdf
# 2026-02-14 22:51:25,861 - INFO : Finished converting document 183-001.pdf in 149.96 sec.
# 2026-02-14 22:51:25,889 - INFO : Parsing completed.
# 2026-02-14 22:51:25,889 - INFO : Transforming output to ParsingResult...
# 2026-02-14 22:51:25,901 - WARNING : Missing mapping for label 'FORMULA' in DOCLING.
# 2026-02-14 22:51:26,079 - INFO : Transformation completed
# 2026-02-14 22:51:26,091 - INFO : Parsing Time: 149.99s
# 2026-02-14 22:51:26,116 - INFO : Adding span-level bounding boxes for: 183-001
# 2026-02-14 22:51:32,101 - INFO : Markdown output saved at: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/markdown/docling/awmf/183-001.md
# 2026-02-14 22:51:32,264 - INFO : JSON output saved at: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/bounding-boxes/docling/awmf/183-001.json
# 2026-02-14 22:51:32,636 - INFO : Parsing 065-003 using DOCLING...
# 2026-02-14 22:51:32,637 - INFO : detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-02-14 22:51:32,646 - INFO : Going to convert document batch...
# 2026-02-14 22:51:32,646 - INFO : Processing document 065-003.pdf
# 2026-02-14 22:53:10,082 - INFO : Finished converting document 065-003.pdf in 97.45 sec.
# 2026-02-14 22:53:10,104 - INFO : Parsing completed.
# 2026-02-14 22:53:10,104 - INFO : Transforming output to ParsingResult...
# 2026-02-14 22:53:10,262 - INFO : Transformation completed
# 2026-02-14 22:53:10,268 - INFO : Parsing Time: 97.47s
# 2026-02-14 22:53:10,277 - INFO : Adding span-level bounding boxes for: 065-003
# 2026-02-14 22:53:14,940 - INFO : Markdown output saved at: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/markdown/docling/awmf/065-003.md
# 2026-02-14 22:53:15,058 - INFO : JSON output saved at: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/bounding-boxes/docling/awmf/065-003.json
# 2026-02-14 22:53:15,463 - INFO : Using 11 documents to create synthetic Chroma evaluation...
# 2026-02-14 22:53:15,494 - INFO : Finished creating chroma corpus at /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/chroma/docling/awmf.txt.
# 0it [00:00, ?it/s]
# 2026-02-14 22:53:15,603 - ERROR : Could not find highlight in document corpus. Searched text: Ruhebeschwerden oder Beschwerden bei geringster
# 2026-02-14 22:53:15,607 - ERROR : Could not find highlight in document corpus. Searched text: 4 CCS 3 CCS 2 CCS 1 CCS
# 2026-02-14 22:53:15,814 - ERROR : Could not find highlight in document corpus. Searched text: Angina pectoris bei leichter körperlicher Belastung (normales Gehen, Ankleiden)
# 2026-02-14 22:53:16,343 - ERROR : Could not find highlight in document corpus. Searched text: Angina pectoris bei stärkerer Anstrengung (schnelles Laufen, Bergaufgehen, Treppensteigen nach dem Essen, bei Kälte, Wind oder psychischer Belastung)
# 2026-02-14 22:53:16,727 - ERROR : Could not find highlight in document corpus. Searched text: Keine Angina pectoris bei Alltagsbelastung (Laufen, Treppensteigen), jedoch bei plötzlicher oder längerer physischer Belastung
# 2026-02-14 22:53:25,147 - ERROR : Could not find highlight in document corpus. Searched text: Tabelle 5: Marburger Herz-Score – Kriterien und Bewertung (nach [14]) Kriterium Punktzahl Geschlecht und Alter (Männer ≥ 55 Jahre und Frauen ≥ 65 Jahre) 1 Bekannte vaskuläre Erkrankung 1 Beschwerden sind belastungsabhängig 1 Schmerzen sind durch Palpation nicht reproduzierbar 1 Der Patient/die Patientin vermutet, dass der Schmerz vom Herzen kommt 1 Für den Score werden die Punkte summiert. Interpretation: Score-Wert 0-2: < 2,5% Wahrscheinlichkeit einer stenosierenden KHK als Ursache des Brustschmerzes ▪ Score-Wert 3: ca. 17% Wahrscheinlichkeit einer stenosierenden KHK als Ursache des Brustschmerzes ▪ Score-Wert 4-5: ca. 50% Wahrscheinlichkeit einer stenosierenden KHK als Ursache des Brustschmerzes ▪ Bei der Interpretation ist stets auch das klinische Gesamtbild zu berücksichtigen.
# 2026-02-14 22:53:26,988 - ERROR : Could not find highlight in document corpus. Searched text: Tabelle 6: Vortestwahrscheinlichkeit für eine stenosierende KHK bei Patient*innen mit stabiler Brust- schmerz-Symptomatik nach dem DISCHARGE Kalkulator (siehe Abbildung 4) typische atypische nicht-anginöse andere Brust- Angina pectoris Angina pectoris Brustschmerzen schmerzen Alter* Frauen Männer Frauen Männer Frauen Männer Frauen Männer [Jahre] 30-39 31% 52% 14% 29% 14% 28% 12% 25% 40-49 38% 59% 19% 36% 18% 35% 15% 31% 50-59 45% 66% 24% 43% 23% 42% 20% 38% 60-69 52% 72% 30% 51% 29% 49% 25% 45% ≥70 60% 78% 37% 58% 36% 57% 32% 52% * Ermittelte Wahrscheinlichkeiten für die Altersgruppen stellen die jeweiligen Schätzwerte für Betroffene im Al- ter von 35, 45, 55, 65 und 75 Jahren dar. Vortestwahrscheinlichkeit in gerundeten Prozentzahlen für die vier Gruppen des Brustschmerzes, gruppiert nach Alter (fünf Altersgruppen) und Geschlecht. Die bildgebenden, diagnostischen Strategien für Patient*innen mit stabilem Brustschmerz und mittleren Risiko für eine stenosierende, koronare Herzkrankheit basieren auf dem DISCHARGE Kalkulator, der auf Basis der COME-CCT (Collaborative Meta-Analysis of Cardiac CT Consortium) Kohorte mittels Individualdaten von Patient*innen mit stabilem Brustschmerz, die für eine invasive Koronarangiographie in Frage kommen, entwickelt wurde.
# 2026-02-14 22:53:27,009 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:53:31,105 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:53:31,106 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:53:31,106 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:53:38,597 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:53:38,598 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:53:38,660 - ERROR : Could not find highlight in document corpus. Searched text:  8-9 2- oder 3-GE und Diabetes mellitus nicht empfohlen
# 2026-02-14 22:53:38,660 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:53:38,660 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:53:38,660 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:53:49,644 - ERROR : Could not find highlight in document corpus. Searched text: Stress-Echokardio- Myokard-Perfusi- Stress-Perfusions- CT-Angiographie ons-Diagnostik graphie MRT (SPECT und PET)
# 2026-02-14 22:53:49,653 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:53:50,251 - ERROR : Could not find highlight in document corpus. Searched text: Konventionelle Systemtherapien Biologika JAK-inhibitoren Azathioprin Ciclosporin Methotrexat Mycofenolat Dupilumab Tralokinumab Abrocitini Baricitinib Upadacitinib mofetil b
# 2026-02-14 22:54:37,622 - ERROR : Could not find highlight in document corpus. Searched text: Konventionelle Systemtherapien Biologika JAK-inhibitoren Azathioprin Ciclosporin Methotrexat Mycofenolat Dupilumab Tralokinumab Abrocitini Baricitinib Upadacitinib mofetil b
# 2026-02-14 22:54:37,724 - ERROR : Could not find highlight in document corpus. Searched text: Tacrolimus 0,1% TCS Klasse I und II TCS Klasse III und IV Pimecrolimus 1% Tacrolimus 0,03%
# 2026-02-14 22:54:37,744 - ERROR : Could not find highlight in document corpus. Searched text: 0.1%)1 ja (0.03% &
# 2026-02-14 22:54:38,322 - ERROR : Could not find highlight in document corpus. Searched text: Anamnese (modifiziert nach [11]) Anamneseinhalte Bezugnahme auf ausführlichen Fragebogen für rau- Exposition gegenüber  chende Patient*innen mit COPD (siehe Abbildung 2) Tabakrauch  oder (aktiv: In Packungsjahren (pack-years; werden vom in verkürzter Form: Arzt oder von der Ärztin berechnet) sowie passiv)  Rauchen Sie (noch)? und  anderen Risikofaktoren Seit wann?   Welche Tabakprodukte?  Wie viele pro Tag?  Beschwerden (wann bestehen Symptome wie Atemnot, Husten und Auswurf) Häufigkeit von Exazerbationen mit und ohne Krankenhausaufenthalt1 Arbeitsanamnese, einschließlich Schadstoffexpositionen Lungenkrankheiten in der Familienanamnese (inklusive Suchtanamnese) Frühgeborene Infekte in der Kindheit Angaben über Asthma, Allergien, und andere Lungen- sowie HNO-Erkrankungen Komorbiditäten (siehe Tabelle 8) B-Symptomatik (Fieber, Nachtschweiß, Gewichtsverlust) gegenwärtige Medikation Körperliche Aktivität Für eine strukturierte Erfassung der Exazerbationen kann der MEP-Fragebogen (Monitoring of Exacerbation Probability) [22] 1 (siehe Tabelle 11) herangezogen werden. Nähere Angaben hierzu finden sich im Kapitel 2.7 Strukturierte Symptomerfassung.
# 2026-02-14 22:54:39,999 - ERROR : Could not find highlight in document corpus. Searched text: Abbildung 4: Medikamentöse Langzeitbehandlung Nicht-medikamentöse Maßnahmen & Tabakentwöhnung Medikamentöse Maßnahmen Symptomatik vorrangig Aufgetretene Exazerbationen vorrangig (Ausmaß der Lungenfunktionseinschränkungen berücksichtigen) Mittelgradige Leichte Therapienaiv?1 schwergradige mittelgradige Symptomatik Symptomatik ja nein LAMA oder LABA LAMA + LABA4 Keine Therapie LAMA oder oder oder LAMA + LABA4 SAMA oder SABA LAMA + LABA4 bei Bedarf Eskalationsstufen oder LAMA oder LABA Eskalation auf: Vorbehandelt mit: LAMA LAMA + LABA4 Ggf. Roflumilast3 (als Add On zu LAMA + LABA LAMA + LABA LAMA + LABA4 oder + ICS2, 4 oder LAMA + LABA + ICS) LABA + ICS4
# 2026-02-14 22:54:54,292 - ERROR : Could not find highlight in document corpus. Searched text: Bezüglich ist schon lange aus klinischen Studien bekannt, systemischer Steroide dass die Applikation zu einem erhöhten Intraokulardruck führt
# 2026-02-14 22:54:58,406 - ERROR : Could not find highlight in document corpus. Searched text: Systematische augenärztliche Untersuchung mit = Bestimmung der Sehscharfe; Untersuchung der vorderen Augenabschnitte; binokulare Untersuchung der Netzhaut bei dilatierter Pupille. nn Ha Arc da Hr Ar DA cemnwntenbinnnknwne I a
# 2026-02-14 22:55:04,788 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:04,789 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:04,791 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:04,801 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:04,803 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:08,987 - ERROR : Could not find highlight in document corpus. Searched text: 1. Bei fortgeschrittener, nicht proliferativer Retinopathie kann eine panretinale Laserkoat 2. Additiv oder alternatv eventuell fokale Laserkoagulation 3. In ausgewählten Fällen kann eine IVOM vor oder anstatt einer PRP erfolgen. 4. Bei fehlender Visusprognose (Visus < 0,05) solte keine IVOM-Therapie erfolgen. ete Version aus NVL Diabelische Retinopathie
# 2026-02-14 22:55:09,313 - ERROR : Could not find highlight in document corpus. Searched text: Zur Therapie einer proliferativen diabetischen Retinopathie (PDR) soll eine panretinale Laserkoagulation erfolgen.
# 2026-02-14 22:55:09,328 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:12,362 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:19,865 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:19,866 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:19,875 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:21,824 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:21,830 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:21,831 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:26,105 - ERROR : Could not find highlight in document corpus. Searched text: B 2
# 2026-02-14 22:55:26,107 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:26,108 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:28,462 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:55:30,466 - ERROR : Could not find highlight in document corpus. Searched text: ⇑⇑ EK
# 2026-02-14 22:55:32,309 - ERROR : Could not find highlight in document corpus. Searched text: ⇔ EK
# 2026-02-14 22:55:43,010 - ERROR : Could not find highlight in document corpus. Searched text: ⇑⇑ EK
# 2026-02-14 22:55:43,055 - ERROR : Could not find highlight in document corpus. Searched text: ⇑⇑ EK
# 2026-02-14 22:55:45,549 - ERROR : Could not find highlight in document corpus. Searched text: ⇑⇑ EK
# 2026-02-14 22:55:45,555 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:56:02,458 - ERROR : Could not find highlight in document corpus. Searched text: Sind Laborwerte im Basislabor oder dem erweiterten Labor Evidenzgrad verändert, sollte ggf. Eine Spezialistin/ein Spezialist in die Expertenkonsens weitere Diagnostik und Therapie einbezogen werden. Konsensstärke 19 von 19 Starker Konsens
# 2026-02-14 22:56:10,141 - ERROR : Could not find highlight in document corpus. Searched text: Grad der Empfehlung A Güte der Evidenz 1 Konsensstärke 17/17 Starker Konsens
# 2026-02-14 22:56:13,110 - ERROR : Could not find highlight in document corpus. Searched text: Grad der Empfehlung A Im Falle einer Bolusgabe soll die Höhe der maximalen Einzeldosis Güte der Evidenz 20000 I.E. nicht überschreiten. Expertenkonsens Konsensstärke 17/17 Starker Konsens
# 2026-02-14 22:56:13,114 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:56:14,239 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:56:15,291 - ERROR : Could not find highlight in document corpus. Searched text:
# 2026-02-14 22:56:22,263 - INFO : Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2026-02-14 22:56:22,312 - INFO : Finished creating evaluation on the medical QA pairs.

# %%
results = []

for chunker in chunkers:
    c_info = chunker.get_info()
    print(c_info)

    c_res = synth_eval.run(chunker, embedding_function, retrieve=-1)
    del c_res["corpora_scores"]

    c_res.update(c_info)
    results.append(c_res)
# Out:
# {'Method': 'Fixed-Size', 'Param': '$O=0$', 'N': 128}
# 2026-02-14 22:57:35,446 - INFO : Chunking 065-003 using FIXED_SIZE...
# Token indices sequence length is longer than the specified maximum sequence length for this model (579 > 512). Running this sequence through the model will result in indexing errors
# 2026-02-14 22:57:35,816 - INFO : Chunking 187-050 using FIXED_SIZE...
# 2026-02-14 22:57:36,200 - INFO : Chunking 045-015 using FIXED_SIZE...
# 2026-02-14 22:57:36,267 - INFO : Chunking 013-027 using FIXED_SIZE...
# 2026-02-14 22:57:37,009 - INFO : Chunking nvl-004 using FIXED_SIZE...
# 2026-02-14 22:57:37,380 - INFO : Chunking 187-019 using FIXED_SIZE...
# 2026-02-14 22:57:37,509 - INFO : Chunking 183-001 using FIXED_SIZE...
# 2026-02-14 22:57:37,940 - INFO : Chunking nvl-003 using FIXED_SIZE...
# 2026-02-14 22:57:38,160 - INFO : Chunking 187-039 using FIXED_SIZE...
# 2026-02-14 22:57:38,241 - INFO : Chunking 045-024 using FIXED_SIZE...
# 2026-02-14 22:57:38,346 - INFO : Chunking 045-028 using FIXED_SIZE...
# 2026-02-14 22:58:11,936 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:13,210 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:14,409 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:15,720 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:19,204 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:20,431 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:21,559 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:23,403 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:25,124 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:26,988 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:28,525 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:29,650 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:30,878 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:32,210 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:33,542 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:34,667 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:35,587 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:36,611 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:37,845 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:39,172 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:40,298 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:41,527 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:42,757 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:44,806 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:45,823 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:46,955 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:48,082 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:49,211 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:50,437 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:51,769 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:53,304 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:54,274 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:55,255 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:56,685 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:58,022 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:58:59,552 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:00,718 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:01,804 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:03,133 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:04,419 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:05,814 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:06,822 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:07,314 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# {'Method': 'Recursive', 'Param': '$O=0$', 'N': 128}
# 2026-02-14 22:59:09,395 - INFO : Chunking 065-003 using RECURSIVE...
# 2026-02-14 22:59:09,755 - INFO : Chunking 187-050 using RECURSIVE...
# 2026-02-14 22:59:10,157 - INFO : Chunking 045-015 using RECURSIVE...
# 2026-02-14 22:59:10,224 - INFO : Chunking 013-027 using RECURSIVE...
# 2026-02-14 22:59:10,767 - INFO : Chunking nvl-004 using RECURSIVE...
# 2026-02-14 22:59:11,156 - INFO : Chunking 187-019 using RECURSIVE...
# 2026-02-14 22:59:11,286 - INFO : Chunking 183-001 using RECURSIVE...
# 2026-02-14 22:59:11,734 - INFO : Chunking nvl-003 using RECURSIVE...
# 2026-02-14 22:59:11,961 - INFO : Chunking 187-039 using RECURSIVE...
# 2026-02-14 22:59:12,041 - INFO : Chunking 045-024 using RECURSIVE...
# 2026-02-14 22:59:12,151 - INFO : Chunking 045-028 using RECURSIVE...
# 2026-02-14 22:59:31,500 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:32,523 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:33,551 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:35,310 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:36,507 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:37,746 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:38,873 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:39,999 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:40,926 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:41,942 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:42,648 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:43,685 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:44,741 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:45,833 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:46,737 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:47,791 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:48,805 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:49,622 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:50,644 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:51,671 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:52,699 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:53,617 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:54,532 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:55,356 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:56,382 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:57,407 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:58,225 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 22:59:59,856 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:01,504 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:02,937 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:04,166 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:05,394 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:06,611 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:07,647 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:08,979 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:10,003 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:11,129 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:12,416 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:13,485 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:14,508 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:15,532 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:16,760 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:17,784 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:18,933 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:20,180 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:21,228 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:22,494 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:23,929 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:25,260 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:26,486 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:28,432 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:29,457 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:30,993 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:32,016 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:33,352 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:34,458 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:35,716 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:36,847 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:38,059 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:38,878 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:00:39,579 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# {'Method': 'Semantic', 'Param': '$Q=95$', 'N': 128}
# 2026-02-14 23:00:42,209 - INFO : Chunking 065-003 using SEMANTIC...
# 2026-02-14 23:01:40,542 - INFO : Chunking 187-050 using SEMANTIC...
# 2026-02-14 23:02:51,160 - INFO : Chunking 045-015 using SEMANTIC...
# 2026-02-14 23:02:59,184 - INFO : Chunking 013-027 using SEMANTIC...
# 2026-02-14 23:03:52,211 - INFO : Chunking nvl-004 using SEMANTIC...
# 2026-02-14 23:05:03,246 - INFO : Chunking 187-019 using SEMANTIC...
# 2026-02-14 23:05:20,013 - INFO : Chunking 183-001 using SEMANTIC...
# 2026-02-14 23:06:54,200 - INFO : Chunking nvl-003 using SEMANTIC...
# 2026-02-14 23:07:35,029 - INFO : Chunking 187-039 using SEMANTIC...
# 2026-02-14 23:07:48,791 - INFO : Chunking 045-024 using SEMANTIC...
# 2026-02-14 23:08:07,478 - INFO : Chunking 045-028 using SEMANTIC...
# 2026-02-14 23:08:31,666 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:32,742 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:33,716 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:34,735 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:35,964 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:37,193 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:38,322 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:39,447 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:40,473 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:41,598 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:42,621 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:43,736 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:44,743 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:45,589 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:46,612 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:48,004 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:49,276 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:54,470 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:57,675 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:08:59,464 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:01,362 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:02,661 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:04,054 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:05,353 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:06,686 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:07,815 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:09,041 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:10,064 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:11,293 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:12,420 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:13,444 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:14,568 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:15,799 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:16,894 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:17,949 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:18,871 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:19,998 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:21,331 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:22,373 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:23,479 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:24,435 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:25,520 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:26,861 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:28,312 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:29,622 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:30,704 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:31,775 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:33,008 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:34,318 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:35,774 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:36,686 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:38,021 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:39,146 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:40,274 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:41,402 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:42,525 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:43,857 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:44,948 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:46,112 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:47,235 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:48,247 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:09:48,879 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# {'Method': 'Hierarchical', 'Param': '$B_h=51$', 'N': 128}
# 2026-02-14 23:09:51,932 - INFO : Chunking 065-003 using HIERARCHICAL...
# 2026-02-14 23:09:52,950 - INFO : Chunking 187-050 using HIERARCHICAL...
# 2026-02-14 23:09:54,136 - INFO : Chunking 045-015 using HIERARCHICAL...
# 2026-02-14 23:09:54,277 - INFO : Chunking 013-027 using HIERARCHICAL...
# 2026-02-14 23:09:55,083 - INFO : Chunking nvl-004 using HIERARCHICAL...
# 2026-02-14 23:09:56,223 - INFO : Chunking 187-019 using HIERARCHICAL...
# 2026-02-14 23:09:56,751 - INFO : Chunking 183-001 using HIERARCHICAL...
# 2026-02-14 23:09:58,001 - INFO : Chunking nvl-003 using HIERARCHICAL...
# 2026-02-14 23:09:58,634 - INFO : Chunking 187-039 using HIERARCHICAL...
# 2026-02-14 23:09:58,821 - INFO : Chunking 045-024 using HIERARCHICAL...
# 2026-02-14 23:09:59,197 - INFO : Chunking 045-028 using HIERARCHICAL...
# 2026-02-14 23:15:00,686 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:02,630 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:03,858 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:04,781 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:06,491 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:07,852 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:08,982 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:10,110 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:11,334 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:12,254 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:13,384 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:14,300 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:15,432 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:16,307 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:17,582 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:18,507 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:19,729 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:21,060 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:22,085 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:23,109 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:24,340 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:25,464 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:26,429 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:27,395 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:28,844 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:30,072 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:31,007 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:32,021 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:33,145 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:34,066 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:34,871 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:36,015 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:37,245 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:38,675 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:39,801 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:40,824 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:41,952 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:42,976 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:43,998 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:45,022 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:46,129 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:47,381 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:48,245 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:49,531 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:50,760 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:51,637 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:52,910 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:54,084 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:55,162 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:56,187 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:57,105 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:58,130 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:15:59,259 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:00,247 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:01,019 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:01,920 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:02,840 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:03,970 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:04,993 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:06,223 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:07,348 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:08,267 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:09,292 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:10,210 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:11,340 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:12,363 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:13,389 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:14,005 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-14 23:16:14,502 - INFO : HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
res_df = pd.DataFrame(results)
res_df.set_index(["Method", "Param"], inplace=True)
res_df.index.names = [None, None]
res_df
# Out:
#                        iou_mean   iou_std  recall_mean  recall_std  \
# Fixed-Size   $O=0$     0.101169  0.108062     0.286600    0.288482
# Recursive    $O=0$     0.120452  0.154260     0.262148    0.283180
# Semantic     $Q=95$    0.120546  0.152881     0.266085    0.283141
# Hierarchical $B_h=51$  0.163110  0.196354     0.320684    0.282656
#
#                        precision_omega_mean  precision_omega_std  \
# Fixed-Size   $O=0$                 0.422392             0.111360
# Recursive    $O=0$                 0.591056             0.145471
# Semantic     $Q=95$                0.591215             0.152295
# Hierarchical $B_h=51$              0.617073             0.165706
#
#                        precision_mean  precision_std    N
# Fixed-Size   $O=0$           0.123153       0.116951  128
# Recursive    $O=0$           0.157335       0.169730  128
# Semantic     $Q=95$          0.157320       0.167997  128
# Hierarchical $B_h=51$        0.213247       0.216891  128

# %%
def combine_cols(df, metric_name: str):
    mean_col = f"{metric_name}_mean"
    std_col = f"{metric_name}_std"

    sorted_mean = df[mean_col].round(2).unique()
    sorted_mean.sort()

    max_val = sorted_mean[-1]
    second_val = sorted_mean[-2]

    def highlight_str(row):
        mean = round(row[mean_col], 2)
        std = round(row[std_col], 2)
        cell = fr"{mean:.2f} \pm {std:.2f}"

        if mean == max_val:
            return fr"$\mathbf{{{cell}}}$"
        elif mean == second_val:
            return fr"\underline{{${cell}$}}"
        else:
            return f"${cell}$"

    df[metric_name.capitalize()] = df.apply(highlight_str, axis=1)

# %%
combined_df = res_df.copy()

combine_cols(combined_df, "iou")
combine_cols(combined_df, "precision")
combine_cols(combined_df, "recall")
combine_cols(combined_df, "precision_omega")

combined_df = combined_df[["N", "Iou", "Recall", "Precision", "Precision_omega"]]
combined_df = combined_df.rename(columns={
    "Iou": "IoU",
    "Precision_omega": r"$\text{Precision}_\Omega$"
})

export_table_to_latex(
    combined_df,
    name="chroma_results",
    column_format="llccccc",
    escape_latex=False,
    highlight_mode=None,
)
# Out:
# 2026-02-14 23:17:43,256 - INFO : Saved table content to: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/thesis/figures/tables/chroma_results.tex
