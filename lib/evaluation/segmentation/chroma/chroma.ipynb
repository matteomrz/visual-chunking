# %% [markdown]
# # Parsing Evaluation with Chroma

# %%
# %load_ext autoreload
# %autoreload 2
from chunking_evaluation import GeneralEvaluation
from dotenv import load_dotenv
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction

import pandas as pd
import numpy as np

from lib.evaluation.segmentation.chroma.chroma_adapter import ChromaChunker
from lib.evaluation.segmentation.chroma.chroma_setup import setup_synthetic_evaluation
from lib.parsing.methods.parsers import Parsers
from lib.segmentation.methods.implementations.fixed_sized import FixedSizeChunker
from lib.segmentation.methods.implementations.recursive import RecursiveChunker
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
chunkers = [
    FixedSizeChunker(max_tokens=800, overlap=400),
    RecursiveChunker(max_tokens=800, overlap=400),
    FixedSizeChunker(max_tokens=400, overlap=200),
    RecursiveChunker(max_tokens=400, overlap=200),
    FixedSizeChunker(max_tokens=400, overlap=0),
    RecursiveChunker(max_tokens=400, overlap=0),
    FixedSizeChunker(max_tokens=200, overlap=0),
    RecursiveChunker(max_tokens=200, overlap=0),
]
# Out:
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <IPython.extensions.autoreload.AutoreloadMagics object at 0x1101e1fd0>> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/IPython/extensions/autoreload.py:867, in AutoreloadMagics.post_execute_hook(self)
#     858     if (
#     859         hasattr(self, "_last_execution_info")
#     860         and self._last_execution_info
#     861         and self._last_execution_info.transformed_cell
#     862     ):
#     863         self._track_imports_from_code(
#     864             self._last_execution_info.transformed_cell
#     865         )
# --> 867 newly_loaded_modules = set(sys.modules) - self.loaded_modules
#     868 for modname in newly_loaded_modules:
#     869     _, pymtime = self._reloader.filename_and_mtime(sys.modules[modname])
#
# KeyboardInterrupt:

# %%
chunkers = [
    ChromaChunker(c) for c in chunkers
]

# %%
# Make sure "OPENAI_API_KEY" is set in a .env file
load_dotenv()
embedding_function = OpenAIEmbeddingFunction(model_name="text-embedding-3-small")

# %% [markdown]
# ## General Evaluation (predefined data sets)

# %%
evaluation = GeneralEvaluation()

results = []
pubmed_results = []

for chunker in chunkers:
    c_info = chunker.get_info()

    c_res = evaluation.run(chunker, embedding_function)
    pubmed_scores = c_res["corpora_scores"]["pubmed"]
    del c_res["corpora_scores"]

    # Add method info to all-corpus-mean scores
    c_res.update(c_info)
    results.append(c_res)

    # Get data for pubmed only
    c_row = {}
    for metric, scores in pubmed_scores.items():
        metric_name = metric.replace("_scores", "")
        c_row[f"{metric_name}_mean"] = np.mean(scores)
        c_row[f"{metric_name}_std"] = np.std(scores)

    c_row.update(c_info)
    pubmed_results.append(c_row)
# Out:
# 2025-12-15 19:02:13,685 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:02:15,835 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:02:15,838 - INFO - Retrying request to /embeddings in 4.923000 seconds
# 2025-12-15 19:02:23,719 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:02:25,253 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:02:25,256 - INFO - Retrying request to /embeddings in 5.505000 seconds
# 2025-12-15 19:02:32,935 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:02:35,569 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:02:35,571 - INFO - Retrying request to /embeddings in 6.867000 seconds
# 2025-12-15 19:02:44,712 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:02:46,551 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:02:46,553 - INFO - Retrying request to /embeddings in 7.057000 seconds
# 2025-12-15 19:02:55,966 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:02:57,817 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:02:57,820 - INFO - Retrying request to /embeddings in 6.807000 seconds
# 2025-12-15 19:03:06,736 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:03:08,057 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:03:08,060 - INFO - Retrying request to /embeddings in 8.344000 seconds
# 2025-12-15 19:03:19,323 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:03:21,675 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:03:24,134 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:03:24,137 - INFO - Retrying request to /embeddings in 4.335000 seconds
# 2025-12-15 19:03:30,375 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:03:32,120 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:03:32,122 - INFO - Retrying request to /embeddings in 4.787000 seconds
# 2025-12-15 19:03:38,779 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:03:39,721 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:03:39,723 - INFO - Retrying request to /embeddings in 5.532000 seconds
# 2025-12-15 19:03:47,688 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:03:48,915 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:03:48,917 - INFO - Retrying request to /embeddings in 4.425000 seconds
# 2025-12-15 19:03:55,162 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:03:56,800 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:03:56,803 - INFO - Retrying request to /embeddings in 4.118000 seconds
# 2025-12-15 19:04:03,151 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:04:04,994 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:04:07,040 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:04:07,043 - INFO - Retrying request to /embeddings in 3.103000 seconds
# 2025-12-15 19:04:11,943 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:04:13,393 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:04:13,396 - INFO - Retrying request to /embeddings in 3.245000 seconds
# 2025-12-15 19:04:19,022 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:04:20,234 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:04:20,237 - INFO - Retrying request to /embeddings in 2.350000 seconds
# 2025-12-15 19:04:24,142 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:04:25,384 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:04:25,386 - INFO - Retrying request to /embeddings in 3.374000 seconds
# 2025-12-15 19:04:30,082 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:04:31,294 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:04:31,297 - INFO - Retrying request to /embeddings in 2.993000 seconds
# 2025-12-15 19:04:35,816 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:04:36,941 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:04:36,943 - INFO - Retrying request to /embeddings in 2.631000 seconds
# 2025-12-15 19:04:40,648 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:04:41,856 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:04:41,858 - INFO - Retrying request to /embeddings in 0.357000 seconds
# 2025-12-15 19:04:43,189 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:04:45,804 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:04:45,807 - INFO - Retrying request to /embeddings in 4.708000 seconds
# 2025-12-15 19:04:52,815 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:04:54,451 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:04:54,454 - INFO - Retrying request to /embeddings in 4.307000 seconds
# 2025-12-15 19:05:00,699 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:02,131 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:05:02,134 - INFO - Retrying request to /embeddings in 1.872000 seconds
# 2025-12-15 19:05:05,513 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:07,794 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:05:07,796 - INFO - Retrying request to /embeddings in 2.656000 seconds
# 2025-12-15 19:05:12,065 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:13,062 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:05:13,065 - INFO - Retrying request to /embeddings in 4.078000 seconds
# 2025-12-15 19:05:19,336 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:20,563 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:05:20,565 - INFO - Retrying request to /embeddings in 2.340000 seconds
# 2025-12-15 19:05:24,711 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:26,504 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:28,447 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:05:28,450 - INFO - Retrying request to /embeddings in 1.371000 seconds
# 2025-12-15 19:05:31,585 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:32,395 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:05:32,397 - INFO - Retrying request to /embeddings in 1.639000 seconds
# 2025-12-15 19:05:35,352 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:36,427 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:05:36,429 - INFO - Retrying request to /embeddings in 1.713000 seconds
# 2025-12-15 19:05:39,855 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:40,529 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:05:40,531 - INFO - Retrying request to /embeddings in 1.638000 seconds
# 2025-12-15 19:05:43,503 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:44,730 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:05:44,732 - INFO - Retrying request to /embeddings in 1.267000 seconds
# 2025-12-15 19:05:47,191 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:48,827 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:51,897 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:53,101 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:05:53,103 - INFO - Retrying request to /embeddings in 0.752000 seconds
# 2025-12-15 19:05:55,073 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:55,987 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:05:55,987 - INFO - Retrying request to /embeddings in 1.230000 seconds
# 2025-12-15 19:05:58,659 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:05:59,729 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:05:59,731 - INFO - Retrying request to /embeddings in 0.747000 seconds
# 2025-12-15 19:06:01,935 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:06:02,827 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:06:02,830 - INFO - Retrying request to /embeddings in 0.534000 seconds
# 2025-12-15 19:06:04,449 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:06:05,721 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:06:05,723 - INFO - Retrying request to /embeddings in 0.210000 seconds
# 2025-12-15 19:06:07,158 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:06:08,049 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 429 Too Many Requests"
# 2025-12-15 19:06:08,050 - INFO - Retrying request to /embeddings in 0.559000 seconds
# 2025-12-15 19:06:10,148 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-15 19:06:11,355 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
pd.DataFrame(results)
# Out:
#    iou_mean   iou_std  recall_mean  recall_std  precision_omega_mean  \
# 0  0.013484  0.011374     0.879179    0.316866              0.045663
# 1  0.016023  0.014594     0.856036    0.346719              0.068034
# 2  0.027950  0.021816     0.918900    0.256813              0.084153
# 3  0.031794  0.028440     0.865487    0.334225              0.126718
# 4  0.026476  0.022138     0.862473    0.326714              0.120204
# 5  0.032294  0.027930     0.871127    0.326619              0.147479
# 6  0.051228  0.041949     0.863683    0.308166              0.209428
# 7  0.063458  0.051763     0.866807    0.318831              0.260989
#
#    precision_omega_std  precision_mean  precision_std            method  \
# 0             0.030262        0.013488       0.011375  FixedSizeChunker
# 1             0.053831        0.016026       0.014596  RecursiveChunker
# 2             0.052076        0.027974       0.021823  FixedSizeChunker
# 3             0.087666        0.031812       0.028453  RecursiveChunker
# 4             0.078366        0.026504       0.022146  FixedSizeChunker
# 5             0.100532        0.032322       0.027967  RecursiveChunker
# 6             0.122358        0.051415       0.042049  FixedSizeChunker
# 7             0.155548        0.063774       0.052115  RecursiveChunker
#
#    max_tokens  overlap
# 0         800      400
# 1         800      400
# 2         400      200
# 3         400      200
# 4         400        0
# 5         400        0
# 6         200        0
# 7         200        0

# %%
pd.DataFrame(pubmed_results)
# Out:
#    precision_omega_mean  precision_omega_std  iou_mean   iou_std  recall_mean  \
# 0              0.060083             0.034847  0.018083  0.013557     0.845734
# 1              0.081863             0.058511  0.022484  0.018533     0.819775
# 2              0.107507             0.058727  0.035788  0.025321     0.845141
# 3              0.163856             0.107700  0.042158  0.040043     0.747848
# 4              0.154159             0.095123  0.032689  0.026631     0.770264
# 5              0.196211             0.123951  0.042903  0.036476     0.784855
# 6              0.252038             0.134686  0.056718  0.047214     0.712142
# 7              0.316290             0.175872  0.080664  0.062101     0.775903
#
#    recall_std  precision_mean  precision_std            method  max_tokens  \
# 0    0.343335        0.018092       0.013557  FixedSizeChunker         800
# 1    0.374184        0.022491       0.018531  RecursiveChunker         800
# 2    0.334229        0.035877       0.025315  FixedSizeChunker         400
# 3    0.420396        0.042213       0.040062  RecursiveChunker         400
# 4    0.393299        0.032753       0.026622  FixedSizeChunker         400
# 5    0.397697        0.042998       0.036575  RecursiveChunker         400
# 6    0.396310        0.057334       0.047538  FixedSizeChunker         200
# 7    0.373964        0.081804       0.063000  RecursiveChunker         200
#
#    overlap
# 0      400
# 1      400
# 2      200
# 3      200
# 4        0
# 5        0
# 6        0
# 7        0

# %% [markdown]
# ## Synthetic Evaluation

# %%
synth_eval = setup_synthetic_evaluation(Parsers.DOCLING, "batch_1", query_exist_ok=True)
# Out:
# 4it [00:00, 90.17it/s]
# 2025-12-13 20:20:42,416 - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# Skipping Document: ESMO_Breast_Cancer. Output JSON already exists.
# Skipping Document: NCCN_breast_p1. Output JSON already exists.
# Skipping Document: NCCN_breast. Output JSON already exists.
# Skipping Document: Contouring_ESTRO_breast_and_LAW. Output JSON already exists.
# Info: Scanning /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/chroma/docling/batch_1 for text documents...
# Info: Using 4 documents to create synthetic Chroma dataset...
# Trying Query 0 for /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/chroma/docling/batch_1/ESMO_Breast_Cancer.txt
# 2025-12-13 20:21:08,324 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Trying Query 0 for /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/chroma/docling/batch_1/NCCN_breast_p1.txt
# 2025-12-13 20:21:40,151 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Trying Query 0 for /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/chroma/docling/batch_1/NCCN_breast.txt
# 2025-12-13 20:21:50,552 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Trying Query 0 for /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/chroma/docling/batch_1/Contouring_ESTRO_breast_and_LAW.txt
# 2025-12-13 20:22:28,136 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Success: Created synthetic evaluation!

# %%
synth_res = synth_eval.run(chunker=chunkers[0], embedding_function=embedding_function)
# Out:
# Chunking ESMO_Breast_Cancer using FIXED_SIZE...
# Info: Directory already exists: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/segmentation/fixed_size/docling/batch_1
# Chunking NCCN_breast_p1 using FIXED_SIZE...
# Info: Directory already exists: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/segmentation/fixed_size/docling/batch_1
# Chunking NCCN_breast using FIXED_SIZE...
# Token indices sequence length is longer than the specified maximum sequence length for this model (628 > 512). Running this sequence through the model will result in indexing errors
# Info: Directory already exists: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/segmentation/fixed_size/docling/batch_1
# Chunking Contouring_ESTRO_breast_and_LAW using FIXED_SIZE...
# Info: Directory already exists: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/segmentation/fixed_size/docling/batch_1
# 2025-12-13 20:22:38,889 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-13 20:22:41,959 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-13 20:22:45,649 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-13 20:22:49,548 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-13 20:22:51,790 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
del synth_res["corpora_scores"]

# %%
pd.DataFrame([synth_res])
# Out:
#    iou_mean  iou_std  recall_mean  recall_std  precision_omega_mean  \
# 0  0.035489  0.02647     0.676473    0.428597               0.11777
#
#    precision_omega_std  precision_mean  precision_std
# 0             0.042573        0.036114       0.027236
