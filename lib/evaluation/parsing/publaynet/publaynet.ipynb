# %%
# %load_ext autoreload

from pandas import DataFrame

from lib.parsing.methods.implementations.document_ai import DocumentAIParser
from lib.parsing.methods.implementations.gemini import GeminiParser
from lib.parsing.methods.implementations.unstructured import UnstructuredParser
from lib.parsing.methods.implementations.llamaparse import LlamaParseParser
from lib.parsing.methods.implementations.mineru import MinerUParser
from lib.parsing.methods.implementations.docling import DoclingParser

from lib.utils.export_table import export_table_to_latex
from lib.evaluation.parsing.publaynet.publaynet import (
    create_publaynet_gt,
    evaluate_parser,
    get_class_metrics
)
# Out:
# objc[87140]: Class AVFFrameReceiver is implemented in both /Users/matteo/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/cv2/.dylibs/libavdevice.61.3.100.dylib (0x12b7883a8) and /Users/matteo/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/av/.dylibs/libavdevice.62.1.100.dylib (0x16bd483a8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[87140]: Class AVFAudioReceiver is implemented in both /Users/matteo/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/cv2/.dylibs/libavdevice.61.3.100.dylib (0x12b7883f8) and /Users/matteo/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/av/.dylibs/libavdevice.62.1.100.dylib (0x16bd483f8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.

# %%
f_50_per_class = []
f_50_95_per_class = []


def p_eval(parser):
    coco_eval = evaluate_parser(parser)
    f_50, f_50_95 = get_class_metrics(coco_eval, parser)
    f_50_per_class.append(f_50)
    f_50_95_per_class.append(f_50_95)


create_publaynet_gt(-1, exist_ok=True)

p_eval(UnstructuredParser())
p_eval(DoclingParser(use_vlm=False))
p_eval(DoclingParser(use_vlm=True))
p_eval(MinerUParser(use_vlm=False))
p_eval(MinerUParser(use_vlm=True))
p_eval(LlamaParseParser())
p_eval(DocumentAIParser())
p_eval(GeminiParser())

df_50 = DataFrame(f_50_per_class)
df_50_95 = DataFrame(f_50_95_per_class)
# Out:
# 2026-02-13 18:17:12,834 - INFO : Started generating new PubLayNet ground truth file.
# 100%|██████████| 500/500 [00:04<00:00, 124.28it/s]
# 2026-02-13 18:17:19,602 - INFO : Saved ground truth file to /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/publaynet/gt.json
# 2026-02-13 18:17:19,605 - INFO : Evaluating unstructured_io on PubLayNet...
# 2026-02-13 18:17:20,248 - INFO : Evaluate annotation type *bbox*
# 2026-02-13 18:17:20,295 - INFO : COCOeval_opt.evaluate() finished...
# 2026-02-13 18:17:20,295 - INFO : DONE (t=0.05s).
# 2026-02-13 18:17:20,295 - INFO : Accumulating evaluation results...
# 2026-02-13 18:17:20,298 - INFO : COCOeval_opt.accumulate() finished...
# 2026-02-13 18:17:20,299 - INFO : DONE (t=0.00s).
# 2026-02-13 18:17:20,299 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.512
# 2026-02-13 18:17:20,299 - INFO :  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.641
# 2026-02-13 18:17:20,300 - INFO :  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.553
# 2026-02-13 18:17:20,301 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.167
# 2026-02-13 18:17:20,301 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.320
# 2026-02-13 18:17:20,302 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.689
# 2026-02-13 18:17:20,302 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.408
# 2026-02-13 18:17:20,302 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.764
# 2026-02-13 18:17:20,302 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.780
# 2026-02-13 18:17:20,303 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.294
# 2026-02-13 18:17:20,303 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.682
# 2026-02-13 18:17:20,303 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.821
# 2026-02-13 18:17:20,303 - INFO :  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.909
# 2026-02-13 18:17:20,304 - INFO :  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.822
# 2026-02-13 18:17:20,304 - INFO : Finished evaluating unstructured_io.
# 2026-02-13 18:17:20,316 - INFO : Evaluating docling on PubLayNet...
# 2026-02-13 18:17:20,767 - INFO : Evaluate annotation type *bbox*
# 2026-02-13 18:17:20,809 - INFO : COCOeval_opt.evaluate() finished...
# 2026-02-13 18:17:20,809 - INFO : DONE (t=0.04s).
# 2026-02-13 18:17:20,809 - INFO : Accumulating evaluation results...
# 2026-02-13 18:17:20,812 - INFO : COCOeval_opt.accumulate() finished...
# 2026-02-13 18:17:20,813 - INFO : DONE (t=0.00s).
# 2026-02-13 18:17:20,813 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.603
# 2026-02-13 18:17:20,813 - INFO :  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.733
# 2026-02-13 18:17:20,814 - INFO :  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.647
# 2026-02-13 18:17:20,814 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.167
# 2026-02-13 18:17:20,814 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.413
# 2026-02-13 18:17:20,815 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.793
# 2026-02-13 18:17:20,815 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.442
# 2026-02-13 18:17:20,815 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.797
# 2026-02-13 18:17:20,815 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.811
# 2026-02-13 18:17:20,815 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.264
# 2026-02-13 18:17:20,815 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.649
# 2026-02-13 18:17:20,816 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.883
# 2026-02-13 18:17:20,816 - INFO :  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.932
# 2026-02-13 18:17:20,817 - INFO :  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.857
# 2026-02-13 18:17:20,817 - INFO : Finished evaluating docling.
# 2026-02-13 18:17:20,828 - INFO : Evaluating docling_granite on PubLayNet...
# 2026-02-13 18:17:20,937 - WARNING : Found element without geometric information.Setting geom to page origin...
# 2026-02-13 18:17:20,938 - WARNING : Found element without geometric information.Setting geom to page origin...
# 2026-02-13 18:17:21,210 - INFO : Evaluate annotation type *bbox*
# 2026-02-13 18:17:21,243 - INFO : COCOeval_opt.evaluate() finished...
# 2026-02-13 18:17:21,243 - INFO : DONE (t=0.03s).
# 2026-02-13 18:17:21,243 - INFO : Accumulating evaluation results...
# 2026-02-13 18:17:21,245 - INFO : COCOeval_opt.accumulate() finished...
# 2026-02-13 18:17:21,245 - INFO : DONE (t=0.00s).
# 2026-02-13 18:17:21,246 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.388
# 2026-02-13 18:17:21,246 - INFO :  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.474
# 2026-02-13 18:17:21,246 - INFO :  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.415
# 2026-02-13 18:17:21,247 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.088
# 2026-02-13 18:17:21,247 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.290
# 2026-02-13 18:17:21,247 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.422
# 2026-02-13 18:17:21,247 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.370
# 2026-02-13 18:17:21,247 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.568
# 2026-02-13 18:17:21,248 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.575
# 2026-02-13 18:17:21,248 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.141
# 2026-02-13 18:17:21,248 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.402
# 2026-02-13 18:17:21,248 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.563
# 2026-02-13 18:17:21,248 - INFO :  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.659
# 2026-02-13 18:17:21,248 - INFO :  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.606
# 2026-02-13 18:17:21,249 - INFO : Finished evaluating docling_granite.
# 2026-02-13 18:17:21.252 | INFO     | mineru.backend.pipeline.model_init:__init__:209 - DocAnalysis init, this may take some times......
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-02-13 18:17:23.652 | INFO     | mineru.backend.pipeline.model_init:__init__:271 - DocAnalysis init done!
# 2026-02-13 18:17:23.652 | INFO     | mineru.backend.pipeline.pipeline_analyze:custom_model_init:65 - model init cost: 2.3997111320495605
# 2026-02-13 18:17:23,652 - INFO : Evaluating mineru_pipeline on PubLayNet...
# 2026-02-13 18:17:24,145 - INFO : Evaluate annotation type *bbox*
# 2026-02-13 18:17:24,192 - INFO : COCOeval_opt.evaluate() finished...
# 2026-02-13 18:17:24,193 - INFO : DONE (t=0.05s).
# 2026-02-13 18:17:24,193 - INFO : Accumulating evaluation results...
# 2026-02-13 18:17:24,197 - INFO : COCOeval_opt.accumulate() finished...
# 2026-02-13 18:17:24,198 - INFO : DONE (t=0.00s).
# 2026-02-13 18:17:24,199 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.534
# 2026-02-13 18:17:24,201 - INFO :  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.684
# 2026-02-13 18:17:24,202 - INFO :  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.547
# 2026-02-13 18:17:24,203 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.173
# 2026-02-13 18:17:24,204 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.319
# 2026-02-13 18:17:24,205 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.655
# 2026-02-13 18:17:24,205 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.434
# 2026-02-13 18:17:24,206 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.706
# 2026-02-13 18:17:24,206 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.712
# 2026-02-13 18:17:24,206 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.203
# 2026-02-13 18:17:24,207 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.406
# 2026-02-13 18:17:24,207 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.813
# 2026-02-13 18:17:24,208 - INFO :  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.840
# 2026-02-13 18:17:24,209 - INFO :  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.733
# 2026-02-13 18:17:24,210 - INFO : Finished evaluating mineru_pipeline.
# 2026-02-13 18:17:24.314 | INFO     | mineru.utils.engine_utils:get_vlm_engine:32 - Using mlx-engine as the inference engine for VLM.
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# 2026-02-13 18:17:25.953 | INFO     | mineru.backend.vlm.vlm_analyze:get_model:218 - get mlx-engine predictor cost: 1.64s
# 2026-02-13 18:17:25,954 - INFO : Evaluating mineru_vlm on PubLayNet...
# 2026-02-13 18:17:26,440 - INFO : Evaluate annotation type *bbox*
# 2026-02-13 18:17:26,486 - INFO : COCOeval_opt.evaluate() finished...
# 2026-02-13 18:17:26,486 - INFO : DONE (t=0.05s).
# 2026-02-13 18:17:26,486 - INFO : Accumulating evaluation results...
# 2026-02-13 18:17:26,490 - INFO : COCOeval_opt.accumulate() finished...
# 2026-02-13 18:17:26,491 - INFO : DONE (t=0.00s).
# 2026-02-13 18:17:26,492 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.459
# 2026-02-13 18:17:26,493 - INFO :  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.629
# 2026-02-13 18:17:26,495 - INFO :  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.453
# 2026-02-13 18:17:26,496 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.088
# 2026-02-13 18:17:26,497 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.354
# 2026-02-13 18:17:26,498 - INFO :  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.596
# 2026-02-13 18:17:26,498 - INFO :  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0
Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.819
# 2026-02-13 18:17:29,258 - INFO :  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.680
# 2026-02-13 18:17:29,260 - INFO : Finished evaluating gemini.

# %%
df_50
# Out:
#                          text     title      list     table    figure  \
# Unstructured.io      0.812313  0.803179  0.663778  0.933735  0.613848
# Docling              0.868700  0.877524  0.802190  0.953027  0.595071
# Granite Docling      0.673736  0.630929  0.632928  0.900120  0.181113
# MinerU 2.5 Pipeline  0.873526  0.955820  0.477108  0.978369  0.653447
# MinerU 2.5 VLM       0.911902  0.882168  0.570194  0.979625  0.250781
# LlamaParse           0.771083  0.637026  0.000000  0.683096  0.000000
# Document AI          0.783022  0.978864  0.000000  0.991093  0.984772
# Gemini 2.5 Flash     0.824157  0.761860  0.410679  0.872475  0.653006
#
#                           all
# Unstructured.io      0.777959
# Docling              0.855520
# Granite Docling      0.598883
# MinerU 2.5 Pipeline  0.854495
# MinerU 2.5 VLM       0.859933
# LlamaParse           0.703132
# Document AI          0.819726
# Gemini 2.5 Flash     0.792299

# %%
df_50_95
# Out:
#                          text     title      list     table    figure  \
# Unstructured.io      0.758330  0.602866  0.572176  0.870709  0.498703
# Docling              0.820642  0.631126  0.740605  0.914278  0.495166
# Granite Docling      0.624125  0.430189  0.569447  0.849680  0.160787
# MinerU 2.5 Pipeline  0.809724  0.616971  0.433118  0.940654  0.543604
# MinerU 2.5 VLM       0.803198  0.446107  0.490569  0.940944  0.203374
# LlamaParse           0.723951  0.305651  0.000000  0.659364  0.000000
# Document AI          0.713554  0.659461  0.000000  0.966871  0.952391
# Gemini 2.5 Flash     0.734720  0.500158  0.319541  0.763644  0.582187
#
#                           all
# Unstructured.io      0.669134
# Docling              0.730433
# Granite Docling      0.514071
# MinerU 2.5 Pipeline  0.718945
# MinerU 2.5 VLM       0.656812
# LlamaParse           0.573794
# Document AI          0.666256
# Gemini 2.5 Flash     0.644116

# %%
df_diff = df_50 - df_50_95
df_diff
# Out:
#                          text     title      list     table    figure  \
# Docling              0.048058  0.246399  0.061585  0.038748  0.099905
# Document AI          0.069468  0.319403  0.000000  0.024222  0.032380
# Gemini 2.5 Flash     0.089437  0.261702  0.091138  0.108832  0.070819
# Granite Docling      0.049612  0.200740  0.063480  0.050441  0.020326
# LlamaParse           0.047132  0.331375  0.000000  0.023732  0.000000
# MinerU 2.5 Pipeline  0.063802  0.338849  0.043990  0.037716  0.109843
# MinerU 2.5 VLM       0.108704  0.436061  0.079626  0.038681  0.047407
# Unstructured.io      0.053983  0.200313  0.091601  0.063026  0.115145
#
#                           all
# Docling              0.125087
# Document AI          0.153470
# Gemini 2.5 Flash     0.148182
# Granite Docling      0.084812
# LlamaParse           0.129338
# MinerU 2.5 Pipeline  0.135550
# MinerU 2.5 VLM       0.203121
# Unstructured.io      0.108825

# %%
export_table_to_latex(df_50, "f_50_publaynet")
export_table_to_latex(df_50_95, "f_50_95_publaynet")
export_table_to_latex(df_diff, "f_diff_publaynet", highlight_mode=False)
# Out:
# 2026-02-13 22:14:15,563 - INFO : Saved table content to: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/thesis/figures/tables/f_50_publaynet.tex
# 2026-02-13 22:14:15,570 - INFO : Saved table content to: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/thesis/figures/tables/f_50_95_publaynet.tex
# 2026-02-13 22:14:15,578 - INFO : Saved table content to: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/thesis/figures/tables/f_diff_publaynet.tex
