# %%
# %load_ext autoreload

from pandas import DataFrame

from lib.parsing.methods.implementations.document_ai import DocumentAIParser
from lib.parsing.methods.implementations.gemini import GeminiParser
from lib.parsing.methods.implementations.unstructured import UnstructuredParser
from lib.parsing.methods.implementations.llamaparse import LlamaParseParser
from lib.parsing.methods.implementations.mineru import MinerUParser
from lib.parsing.methods.implementations.docling import DoclingParser

from lib.utils.export_table import export_table_to_latex
from lib.evaluation.parsing.publaynet.publaynet import (
    create_publaynet_gt,
    evaluate_parser,
    get_class_metrics
)
# Out:
# objc[33134]: Class AVFFrameReceiver is implemented in both /Users/matteo/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/cv2/.dylibs/libavdevice.61.3.100.dylib (0x1488703a8) and /Users/matteo/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/av/.dylibs/libavdevice.62.1.100.dylib (0x174da03a8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[33134]: Class AVFAudioReceiver is implemented in both /Users/matteo/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/cv2/.dylibs/libavdevice.61.3.100.dylib (0x1488703f8) and /Users/matteo/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/av/.dylibs/libavdevice.62.1.100.dylib (0x174da03f8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.

# %%
f_50_per_class = []
f_50_95_per_class = []


def p_eval(parser):
    coco_eval = evaluate_parser(parser)
    f_50, f_50_95 = get_class_metrics(coco_eval, parser)
    f_50_per_class.append(f_50)
    f_50_95_per_class.append(f_50_95)


create_publaynet_gt(-1, exist_ok=True)

p_eval(UnstructuredParser())
p_eval(DoclingParser(use_vlm=False))
p_eval(DoclingParser(use_vlm=True))
p_eval(MinerUParser(use_vlm=False))
p_eval(MinerUParser(use_vlm=True))
p_eval(LlamaParseParser())
p_eval(DocumentAIParser())
p_eval(GeminiParser())

df_50 = DataFrame(f_50_per_class)
df_50_95 = DataFrame(f_50_95_per_class)
# Out:
# 2026-02-11 19:55:00,320 - INFO : Started generating new PubLayNet ground truth file.
# 100%|██████████| 500/500 [00:04<00:00, 120.39it/s]
# 2026-02-11 19:55:07,936 - INFO : Saved ground truth file to /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/publaynet/gt.json
# 2026-02-11 19:55:07,939 - INFO : Evaluating unstructured_io on PubLayNet...
# 2026-02-11 19:55:08,656 - INFO : Finished evaluating unstructured_io.
# 2026-02-11 19:55:08,663 - INFO : Evaluating docling on PubLayNet...
# 2026-02-11 19:55:09,154 - INFO : Finished evaluating docling.
# 2026-02-11 19:55:09,160 - INFO : Evaluating docling_granite on PubLayNet...
# 2026-02-11 19:55:09,272 - WARNING : Found element without geometric information.Setting geom to page origin...
# 2026-02-11 19:55:09,272 - WARNING : Found element without geometric information.Setting geom to page origin...
# 2026-02-11 19:55:09,587 - INFO : Finished evaluating docling_granite.
# 2026-02-11 19:55:09.591 | INFO     | mineru.backend.pipeline.model_init:__init__:209 - DocAnalysis init, this may take some times......
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-02-11 19:55:12.089 | INFO     | mineru.backend.pipeline.model_init:__init__:271 - DocAnalysis init done!
# 2026-02-11 19:55:12.089 | INFO     | mineru.backend.pipeline.pipeline_analyze:custom_model_init:65 - model init cost: 2.498420000076294
# 2026-02-11 19:55:12,089 - INFO : Evaluating mineru_pipeline on PubLayNet...
# 2026-02-11 19:55:12,630 - INFO : Finished evaluating mineru_pipeline.
# 2026-02-11 19:55:12.877 | INFO     | mineru.utils.engine_utils:get_vlm_engine:32 - Using mlx-engine as the inference engine for VLM.
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# 2026-02-11 19:55:14.478 | INFO     | mineru.backend.vlm.vlm_analyze:get_model:259 - get mlx-engine predictor cost: 1.6s
# 2026-02-11 19:55:14,479 - INFO : Evaluating mineru_vlm on PubLayNet...
# 2026-02-11 19:55:15,238 - INFO : Finished evaluating mineru_vlm.
# 2026-02-11 19:55:15,248 - INFO : Evaluating llamaparse on PubLayNet...
# 2026-02-11 19:55:16,161 - INFO : Finished evaluating llamaparse.
# /Users/matteo/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/google/auth/_default.py:114: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# 2026-02-11 19:55:16,894 - INFO : Evaluating document_ai on PubLayNet...
# 2026-02-11 19:55:17,347 - INFO : Finished evaluating document_ai.
# 2026-02-11 19:55:17,410 - INFO : Evaluating gemini on PubLayNet...
# 2026-02-11 19:55:17,875 - INFO : Finished evaluating gemini.

# %%
df_50
# Out:
#                          text     title      list     table    figure  \
# Unstructured.io      0.812313  0.803179  0.126923  0.933735  0.613848
# Docling              0.868700  0.877524  0.802190  0.953027  0.595071
# Granite Docling      0.673736  0.630929  0.632928  0.900120  0.181113
# MinerU 2.5 Pipeline  0.873526  0.955820  0.477108  0.978369  0.653447
# MinerU 2.5 VLM       0.911902  0.882168  0.570194  0.979625  0.250781
# LlamaParse           0.771083  0.637026  0.000000  0.683096  0.000000
# Document AI          0.783022  0.978864  0.000000  0.991093  0.984772
# Gemini 2.5 Flash     0.824157  0.761860  0.127059  0.872475  0.653006
#
#                           all
# Unstructured.io      0.621584
# Docling              0.806310
# Granite Docling      0.529565
# MinerU 2.5 Pipeline  0.652773
# MinerU 2.5 VLM       0.594106
# LlamaParse           0.410951
# Document AI          0.739318
# Gemini 2.5 Flash     0.615318

# %%
df_50_95

# %%
export_table_to_latex(df_50, "f_50_publaynet")
export_table_to_latex(df_50_95, "f_50_95_publaynet")
# Out:
# 2026-02-11 19:55:17,980 - INFO : Saved table content to: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/thesis/figures/tables/f_50_publaynet.tex
# 2026-02-11 19:55:17,985 - INFO : Saved table content to: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/thesis/figures/tables/f_50_95_publaynet.tex
