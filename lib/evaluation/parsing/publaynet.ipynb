# %%
from lib.parsing.methods.implementations.mineru import MinerUParser
# %load_ext autoreload

from pandas import DataFrame

from lib.parsing.methods.implementations.unstructured import UnstructuredParser
from lib.utils.export_to_latex import export_table_to_latex
from lib.evaluation.parsing.publaynet import create_publaynet_gt, evaluate_parser
from lib.parsing.methods.implementations.docling import DoclingParser
# Out:
# 2026-01-11 15:55:31,247 - DEBUG : Successfully initialized Logging.

# %%
results = []


def p_eval(parser):
    p_res = evaluate_parser(parser)
    results.append(p_res)


create_publaynet_gt(20, exist_ok=True)

p_eval(DoclingParser())
p_eval(UnstructuredParser())
p_eval(MinerUParser(use_vlm=False))
p_eval(MinerUParser(use_vlm=True))

df = DataFrame(results)
export_table_to_latex(df, "example_table")
# Out:
# 2026-01-11 15:59:30,466 - INFO : Ground truth file already exists at: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/publaynet/gt.json
# 2026-01-11 15:59:30,472 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-11 15:59:30,473 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-11 15:59:30,474 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-11 15:59:30,475 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-11 15:59:30,475 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-11 15:59:30,476 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-11 15:59:30,477 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-11 15:59:30,481 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-11 15:59:30,481 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-11 15:59:30,483 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-11 15:59:30,484 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-11 15:59:30,484 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-11 15:59:30,485 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-11 15:59:30,486 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-11 15:59:30,487 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-11 15:59:30,489 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-11 15:59:30,490 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-11 15:59:30,491 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-11 15:59:30,492 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-11 15:59:30,493 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-11 15:59:30,547 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-11 15:59:30,547 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-11 15:59:30,548 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-11 15:59:30,549 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-11 15:59:30,549 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-11 15:59:30,551 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-11 15:59:30,552 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-11 15:59:30,552 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-11 15:59:30,553 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-11 15:59:30,554 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-11 15:59:30,554 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-11 15:59:30,555 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-11 15:59:30,556 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-11 15:59:30,556 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-11 15:59:30,557 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-11 15:59:30,558 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-11 15:59:30,558 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-11 15:59:30,558 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-11 15:59:30,559 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-11 15:59:30,560 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-11 15:59:30,589 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-11 15:59:30,590 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-11 15:59:30,590 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-11 15:59:30,591 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-11 15:59:30,591 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-11 15:59:30,592 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-11 15:59:30,592 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-11 15:59:30,593 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-11 15:59:30,594 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-11 15:59:30,594 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-11 15:59:30,595 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-11 15:59:30,595 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-11 15:59:30,596 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-11 15:59:30,597 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-11 15:59:30,597 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-11 15:59:30,598 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-11 15:59:30,598 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-11 15:59:30,599 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-11 15:59:30,600 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-11 15:59:30,600 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-11 15:59:30,630 - INFO : Parsing 166403 using MINERU_VLM...
# 2026-01-11 15:59:30,630 - DEBUG : Directory already exists: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/images/mineru_vlm/publaynet/166403
# 2026-01-11 15:59:31.056 | DEBUG    | mineru.backend.vlm.vlm_analyze:doc_analyze:209 - load images cost: 0.42, speed: 2.381 images/s
# Predict: 100%|██████████| 1/1 [00:11<00:00, 11.72s/it]
# Predict:  71%|███████   | 12/17 [03:08<01:18, 15.72s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 14
#      12 p_eval(UnstructuredParser())
#      13 p_eval(MinerUParser(use_vlm=False))
# ---> 14 p_eval(MinerUParser(use_vlm=True))
#      16 df = DataFrame(results)
#      17 export_table_to_latex(df, "example_table")
#
# Cell In[3], line 5, in p_eval(parser)
#       4 def p_eval(parser):
# ----> 5     p_res = evaluate_parser(parser)
#       6     results.append(p_res)
#
# File ~/Uni/7.Semester/thesis/visual-chunking/lib/evaluation/parsing/publaynet.py:237, in evaluate_parser(parser)
#     234     create_publaynet_gt()
#     236 # Process PubLayNet files
# --> 237 results = parser.process_batch(PUBLAYNET_NAME, _parsing_options)
#     238 coco_eval = _create_evaluation(results[0], parser)
#     240 coco_eval.params.useCats = True
#
# File ~/Uni/7.Semester/thesis/visual-chunking/lib/parsing/model/document_parser.py:266, in DocumentParser.process_batch(self, batch_name, options)
#     264         results.append(res)
#     265     else:
# --> 266         res = self.process_document(file_path, options)
#     267         results.append(res)
#     269 return results
#
# File ~/Uni/7.Semester/thesis/visual-chunking/lib/parsing/model/document_parser.py:218, in DocumentParser.process_document(self, file_path, options)
#     214 logger.info(f"Parsing {file_name} using {self.module.name}...")
#     216 start_time = time.time()
# --> 218 raw_result = self._parse(file_path, options)
#     219 logger.info("Parsing completed.")
#     221 parse_time = time.time()
#
# File ~/Uni/7.Semester/thesis/visual-chunking/lib/parsing/methods/implementations/mineru.py:75, in MinerUParser._parse(self, file_path, options)
#      73 pdf_bytes = _get_pdf_bytes(file_path)
#      74 if self.is_vlm:
# ---> 75     result, _ = vlm_doc_analyze(
#      76         pdf_bytes, image_writer=image_writer, predictor=self.model
#      77     )
#      78 else:
#      79     result = _get_pipeline_result(pdf_bytes, image_writer)
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mineru/backend/vlm/vlm_analyze.py:212, in doc_analyze(pdf_bytes, image_writer, predictor, backend, model_path, server_url, **kwargs)
#     209 logger.debug(f"load images cost: {load_images_time}, speed: {round(len(images_pil_list)/load_images_time, 3)} images/s")
#     211 infer_start = time.time()
# --> 212 results = predictor.batch_two_step_extract(images=images_pil_list)
#     213 infer_time = round(time.time() - infer_start, 2)
#     214 logger.debug(f"infer finished, cost: {infer_time}, speed: {round(len(results)/infer_time, 3)} page/s")
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mineru_vl_utils/mineru_client.py:783, in MinerUClient.batch_two_step_extract(self, images, priority, not_extract_list)
#     781     return self.concurrent_two_step_extract(images, priority, not_extract_list)
#     782 else:  # self.batching_mode == "stepping"
# --> 783     return self.stepping_two_step_extract(images, priority, not_extract_list)
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mineru_vl_utils/mineru_client.py:720, in MinerUClient.stepping_two_step_extract(self, images, priority, not_extract_list)
#     718     all_params.extend(params)
#     719     all_indices.extend([(img_idx, idx) for idx in indices])
# --> 720 outputs = self.client.batch_predict(all_images, all_prompts, all_params, priority)
#     721 for (img_idx, idx), output in zip(all_indices, outputs):
#     722     blocks_list[img_idx][idx].content = output
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mineru_vl_utils/vlm_client/mlx_client.py:129, in MlxVlmClient.batch_predict(self, images, prompts, sampling_params, priority)
#     125 with tqdm(total=images_len, desc="Predict", disable=not self.use_tqdm) as pbar:
#     126
#     127     # Since mlx-vlm's generate function does not support batching, we can only call it in a loop
#     128     for i in range(0, images_len):
# --> 129         result = self.predict(
#     130             image=images[i],
#     131             prompt=prompts[i],
#     132             sampling_params=sampling_params[i],
#     133         )
#     134         results.append(result)
#     135         pbar.update(1)
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mineru_vl_utils/vlm_client/mlx_client.py:100, in MlxVlmClient.predict(self, image, prompt, sampling_params, priority)
#      92 chat_prompt = self.processor.apply_chat_template(
#      93     self.build_messages(prompt),
#      94     tokenize=False,
#      95     add_generation_prompt=True,
#      96 )
#      98 generate_kwargs = self.build_generate_kwargs(sampling_params)
# --> 100 response = self.generate(
#     101     model=self.model,
#     102     processor=self.processor,
#     103     prompt=chat_prompt,
#     104     image=image,
#     105     **generate_kwargs,
#     106 )
#     107 return response.text
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mlx_vlm/generate.py:539, in generate(model, processor, prompt, image, audio, verbose, **kwargs)
#     536 else:
#     537     tokenizer.stopping_criteria.reset(model.config.eos_token_id)
# --> 539 for response in stream_generate(model, processor, prompt, image, audio, **kwargs):
#     540     if verbose:
#     541         print(response.text, end="", flush=True)
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mlx_vlm/generate.py:429, in stream_generate(model, processor, prompt, image, audio, **kwargs)
#     427 detokenizer.reset()
#     428 tic = time.perf_counter()
# --> 429 for n, (token, logprobs) in enumerate(
#     430     generate_step(input_ids, model, pixel_values, mask, **kwargs)
#     431 ):
#     432     if n == 0:
#     433         prompt_time = time.perf_counter() - tic
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mlx_vlm/generate.py:344, in generate_step(input_ids, model, pixel_values, mask, max_tokens, temperature, repetition_penalty, repetition_context_size, top_p, logit_bias, prompt_cache, max_kv_size, kv_bits, kv_group_size, quantized_kv_start, **kwargs)
#     342 while True:
#     343     if n != max_tokens:
# --> 344         next_y, next_logprobs = _step(y, **kwargs)
#     345         mx.async_eval(next_y)
#     346         if "decoder_input_ids" in kwargs:
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mlx_vlm/generate.py:295, in generate_step.<locals>._step(y, **kwargs)
#     290     outputs = model.language_model(
#     291         cache=prompt_cache,
#     292         **kwargs,
#     293     )
#     294 else:
# --> 295     outputs = model.language_model(
#     296         y[None],
#     297         cache=prompt_cache,
#     298         **kwargs,
#     299     )
#     301 logits = outputs.logits[:, -1, :]
#     303 if repetition_penalty:
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mlx_vlm/models/qwen2_vl/language.py:510, in LanguageModel.__call__(self, inputs, inputs_embeds, mask, cache, **kwargs)
#     505         position_ids = mx.add(position_ids, delta)[None, ...]
#     506         position_ids = mx.broadcast_to(
#     507             position_ids, (3, batch_size, seq_length)
#     508         )
# --> 510 out = self.model(
#     511     inputs, cache=cache, inputs_embeds=inputs_embeds, position_ids=position_ids
#     512 )
#     513 if self.args.tie_word_embeddings:
#     514     out = self.model.embed_tokens.as_linear(out)
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mlx_vlm/models/qwen2_vl/language.py:252, in Qwen2Model.__call__(self, inputs, inputs_embeds, mask, cache, position_ids)
#     249     mask = create_attention_mask(h, cache)
#     251 for layer, c in zip(self.layers, cache):
# --> 252     h = layer(h, mask, c, position_ids)
#     254 return self.norm(h)
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mlx_vlm/models/qwen2_vl/language.py:212, in Qwen2VLDecoderLayer.__call__(self, x, mask, cache, position_ids)
#     205 def __call__(
#     206     self,
#     207     x: mx.array,
#    (...)    210     position_ids: Optional[mx.array] = None,
#     211 ) -> mx.array:
# --> 212     r = self.self_attn(self.input_layernorm(x), mask, cache, position_ids)
#     213     h = x + r
#     214     r = self.mlp(self.post_attention_layernorm(h))
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mlx_vlm/models/qwen2_vl/language.py:174, in Attention.__call__(self, x, mask, cache, position_ids)
#     171 if cache is not None:
#     172     keys, values = cache.update_and_fetch(keys, values)
# --> 174 output = scaled_dot_product_attention(
#     175     queries, keys, values, cache, scale=self.scale, mask=mask
#     176 )
#     177 output = output.transpose(0, 2, 1, 3).reshape(B, L, -1)
#     178 return self.o_proj(output)
#
# File ~/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/mlx_lm/models/base.py:108, in scaled_dot_product_attention(queries, keys, values, cache, scale, mask, sinks)
#     103         out = mx.reshape(out, (B, n_q_heads, L, D))
#     105     return out
# --> 108 def scaled_dot_product_attention(
#     109     queries,
#     110     keys,
#     111     values,
#     112     cache,
#     113     scale: float,
#     114     mask: Optional[mx.array],
#     115     sinks: Optional[mx.array] = None,
#     116 ) -> mx.array:
#     117     if hasattr(cache, "bits"):
#     118         if sinks is not None:
#
# KeyboardInterrupt:
