# %%
from lib.parsing.methods.implementations.llamaparse import LlamaParseParser
from lib.parsing.methods.implementations.mineru import MinerUParser
# %load_ext autoreload

from pandas import DataFrame

from lib.parsing.methods.implementations.unstructured import UnstructuredParser
from lib.utils.export_to_latex import export_table_to_latex
from lib.evaluation.parsing.publaynet import create_publaynet_gt, \
    evaluate_parser, get_class_metrics
from lib.parsing.methods.implementations.docling import DoclingParser
# Out:
# 2026-01-23 14:53:16,999 - DEBUG : Successfully initialized Logging.

# %%
results = []


def p_eval(parser):
    coco_eval = evaluate_parser(parser)
    p_res = get_class_metrics(coco_eval, parser)
    results.append(p_res)


create_publaynet_gt(20, exist_ok=True)

p_eval(DoclingParser())
p_eval(UnstructuredParser())
p_eval(MinerUParser(use_vlm=False))
p_eval(MinerUParser(use_vlm=True))
p_eval(LlamaParseParser())

df = DataFrame(results)
export_table_to_latex(df, "example_table")
# Out:
# 2026-01-23 14:53:28,035 - INFO : Ground truth file already exists at: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/publaynet/gt.json
# 2026-01-23 14:53:28,040 - INFO : Evaluating docling on PubLayNet...
# 2026-01-23 14:53:28,041 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-23 14:53:28,042 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-23 14:53:28,043 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-23 14:53:28,043 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-23 14:53:28,044 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-23 14:53:28,045 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-23 14:53:28,046 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-23 14:53:28,048 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-23 14:53:28,049 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-23 14:53:28,050 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-23 14:53:28,051 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-23 14:53:28,052 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-23 14:53:28,054 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-23 14:53:28,055 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-23 14:53:28,055 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-23 14:53:28,056 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-23 14:53:28,057 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-23 14:53:28,058 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-23 14:53:28,058 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-23 14:53:28,059 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-23 14:53:28,087 - INFO : Finished evaluating docling.
# 2026-01-23 14:53:28,089 - INFO : Evaluating unstructured_io on PubLayNet...
# 2026-01-23 14:53:28,090 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-23 14:53:28,091 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-23 14:53:28,091 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-23 14:53:28,092 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-23 14:53:28,092 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-23 14:53:28,093 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-23 14:53:28,093 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-23 14:53:28,094 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-23 14:53:28,094 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-23 14:53:28,094 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-23 14:53:28,095 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-23 14:53:28,095 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-23 14:53:28,096 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-23 14:53:28,097 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-23 14:53:28,097 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-23 14:53:28,098 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-23 14:53:28,098 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-23 14:53:28,098 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-23 14:53:28,099 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-23 14:53:28,099 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-23 14:53:28,115 - INFO : Finished evaluating unstructured_io.
# 2026-01-23 14:53:28.116 | INFO     | mineru.backend.pipeline.model_init:__init__:209 - DocAnalysis init, this may take some times......
# 0.8044835723361772
# 0.6559702379711213
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-01-23 14:53:30.840 | INFO     | mineru.backend.pipeline.model_init:__init__:271 - DocAnalysis init done!
# 2026-01-23 14:53:30.840 | INFO     | mineru.backend.pipeline.pipeline_analyze:custom_model_init:65 - model init cost: 2.724494695663452
# 2026-01-23 14:53:30,841 - INFO : Evaluating mineru_pipeline on PubLayNet...
# 2026-01-23 14:53:30,841 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-23 14:53:30,842 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-23 14:53:30,843 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-23 14:53:30,845 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-23 14:53:30,846 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-23 14:53:30,847 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-23 14:53:30,850 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-23 14:53:30,852 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-23 14:53:30,854 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-23 14:53:30,857 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-23 14:53:30,859 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-23 14:53:30,861 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-23 14:53:30,864 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-23 14:53:30,868 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-23 14:53:30,869 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-23 14:53:30,870 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-23 14:53:30,871 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-23 14:53:30,872 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-23 14:53:30,874 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-23 14:53:30,877 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-23 14:53:30,933 - INFO : Finished evaluating mineru_pipeline.
# 0.6581359171973729
# 2026-01-23 14:53:31.788 | INFO     | mineru.utils.engine_utils:get_vlm_engine:32 - Using mlx-engine as the inference engine for VLM.
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# 2026-01-23 14:53:33.630 | INFO     | mineru.backend.vlm.vlm_analyze:get_model:189 - get mlx-engine predictor cost: 1.84s
# 2026-01-23 14:53:33,630 - INFO : Evaluating mineru_vlm on PubLayNet...
# 2026-01-23 14:53:33,631 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-23 14:53:33,632 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-23 14:53:33,633 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-23 14:53:33,633 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-23 14:53:33,635 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-23 14:53:33,636 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-23 14:53:33,638 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-23 14:53:33,640 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-23 14:53:33,641 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-23 14:53:33,642 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-23 14:53:33,642 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-23 14:53:33,644 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-23 14:53:33,645 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-23 14:53:33,646 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-23 14:53:33,652 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-23 14:53:33,654 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-23 14:53:33,654 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-23 14:53:33,655 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-23 14:53:33,656 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-23 14:53:33,660 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-23 14:53:33,713 - INFO : Finished evaluating mineru_vlm.
# 2026-01-23 14:53:33,752 - INFO : Evaluating llamaparse on PubLayNet...
# 2026-01-23 14:53:33,755 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-23 14:53:33,760 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-23 14:53:33,761 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-23 14:53:33,762 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-23 14:53:33,763 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-23 14:53:33,764 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-23 14:53:33,764 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-23 14:53:33,768 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-23 14:53:33,770 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-23 14:53:33,772 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-23 14:53:33,773 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-23 14:53:33,773 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-23 14:53:33,774 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-23 14:53:33,774 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-23 14:53:33,775 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-23 14:53:33,776 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-23 14:53:33,777 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-23 14:53:33,778 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-23 14:53:33,781 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-23 14:53:33,782 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-23 14:53:33,805 - INFO : Finished evaluating llamaparse.
# /Users/matteo/Uni/7.Semester/thesis/visual-chunking/.venv/lib/python3.13/site-packages/faster_coco_eval/core/faster_eval_api.py:248: RuntimeWarning: invalid value encountered in divide
#   f1_cls = 2 * prec * rec_thrs[:, None] / (prec + rec_thrs[:, None])
# 2026-01-23 14:53:33,856 - INFO : Saved table content to: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/thesis/figures/example_table.tex
# 0.5470708406908118
# 0.4513098245495491

# %%
df
# Out:
#                      text     title      list     table    figure       all
# docling          0.876078  0.884746  0.857143  1.000000  0.769231  0.804484
# unstructured_io  0.801481  0.896010  0.498392  1.000000  0.632199  0.655970
# mineru_pipeline  0.870462  0.962338  0.666667  1.000000  0.689655  0.658136
# mineru_vlm       0.891702  0.931818  0.666667  1.000000  0.400000  0.547071
# llamaparse       0.743004  0.705813  0.000000  0.888889  0.000000  0.451310
