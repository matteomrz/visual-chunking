# %%
from lib.parsing.methods.implementations.mineru import MinerUParser
# %load_ext autoreload

from pandas import DataFrame

from lib.parsing.methods.implementations.unstructured import UnstructuredParser
from lib.utils.export_to_latex import export_table_to_latex
from lib.evaluation.parsing.publaynet import create_publaynet_gt, evaluate_parser
from lib.parsing.methods.implementations.docling import DoclingParser
# Out:
# 2026-01-11 15:09:34,379 - DEBUG : Successfully initialized Logging.

# %%
results = []


def p_eval(parser):
    p_res = evaluate_parser(parser)
    results.append(p_res)


create_publaynet_gt(20)

p_eval(DoclingParser())
p_eval(UnstructuredParser())
p_eval(MinerUParser(use_vlm=False))
p_eval(MinerUParser(use_vlm=True))

df = DataFrame(results)
export_table_to_latex(df, "example_table")
# Out:
# 2026-01-11 15:09:42,983 - INFO : Started generating new PubLayNet ground truth file.
# 2026-01-11 15:09:42,984 - DEBUG : Downloading dataset from kenza-ily/publaynet-mini...
# 2026-01-11 15:09:46,362 - DEBUG : Processing PubLayNet dataset...
# 100%|██████████| 20/20 [00:00<00:00, 71.74it/s]
# 2026-01-11 15:09:46,645 - INFO : Saved ground truth file to /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/publaynet/gt.json
# 2026-01-11 15:09:46,650 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-11 15:09:46,651 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-11 15:09:46,651 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-11 15:09:46,653 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-11 15:09:46,654 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-11 15:09:46,655 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-11 15:09:46,656 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-11 15:09:46,657 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-11 15:09:46,658 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-11 15:09:46,660 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-11 15:09:46,661 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-11 15:09:46,662 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-11 15:09:46,663 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-11 15:09:46,664 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-11 15:09:46,666 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-11 15:09:46,666 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-11 15:09:46,667 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-11 15:09:46,668 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-11 15:09:46,669 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-11 15:09:46,670 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-11 15:09:46,716 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-11 15:09:46,717 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-11 15:09:46,717 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-11 15:09:46,718 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-11 15:09:46,719 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-11 15:09:46,719 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-11 15:09:46,720 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-11 15:09:46,720 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-11 15:09:46,721 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-11 15:09:46,722 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-11 15:09:46,722 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-11 15:09:46,723 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-11 15:09:46,724 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-11 15:09:46,725 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-11 15:09:46,726 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-11 15:09:46,727 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-11 15:09:46,728 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-11 15:09:46,728 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-11 15:09:46,729 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-11 15:09:46,729 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-11 15:09:46,801 - INFO : Saved table content to: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/thesis/figures/example_table.tex
