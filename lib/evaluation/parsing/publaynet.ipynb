# %%
from lib.parsing.methods.implementations.llamaparse import LlamaParseParser
from lib.parsing.methods.implementations.mineru import MinerUParser
# %load_ext autoreload

from pandas import DataFrame

from lib.parsing.methods.implementations.unstructured import UnstructuredParser
from lib.utils.export_to_latex import export_table_to_latex
from lib.evaluation.parsing.publaynet import create_publaynet_gt, evaluate_parser, get_class_metrics
from lib.parsing.methods.implementations.docling import DoclingParser
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 9
#       7 from lib.parsing.methods.implementations.unstructured import UnstructuredParser
#       8 from lib.utils.export_to_latex import export_table_to_latex
# ----> 9 from lib.evaluation.parsing.publaynet import create_publaynet_gt, evaluate_parser, get_class_metrics
#      10 from lib.parsing.methods.implementations.docling import DoclingParser
#
# ImportError: cannot import name 'get_class_metrics' from 'lib.evaluation.parsing.publaynet' (/Users/matteo/Uni/7.Semester/thesis/visual-chunking/lib/evaluation/parsing/publaynet.py)

# %%
results = []


def p_eval(parser):
    coco_eval = evaluate_parser(parser)
    p_res = get_class_metrics(coco_eval, parser)
    results.append(p_res)


create_publaynet_gt(20, exist_ok=True)

p_eval(DoclingParser())
p_eval(UnstructuredParser())
p_eval(MinerUParser(use_vlm=False))
p_eval(MinerUParser(use_vlm=True))
p_eval(LlamaParseParser())

df = DataFrame(results)
export_table_to_latex(df, "example_table")
# Out:
# 2026-01-11 16:33:03,119 - INFO : Ground truth file already exists at: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/publaynet/gt.json
# 2026-01-11 16:33:03,151 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-11 16:33:03,157 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-11 16:33:03,160 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-11 16:33:03,161 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-11 16:33:03,162 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-11 16:33:03,163 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-11 16:33:03,165 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-11 16:33:03,167 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-11 16:33:03,168 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-11 16:33:03,171 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-11 16:33:03,173 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-11 16:33:03,174 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-11 16:33:03,176 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-11 16:33:03,178 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-11 16:33:03,181 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-11 16:33:03,182 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-11 16:33:03,183 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-11 16:33:03,184 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-11 16:33:03,185 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-11 16:33:03,186 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-11 16:33:03,295 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-11 16:33:03,296 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-11 16:33:03,297 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-11 16:33:03,297 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-11 16:33:03,298 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-11 16:33:03,299 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-11 16:33:03,299 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-11 16:33:03,300 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-11 16:33:03,301 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-11 16:33:03,301 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-11 16:33:03,302 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-11 16:33:03,302 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-11 16:33:03,302 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-11 16:33:03,303 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-11 16:33:03,303 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-11 16:33:03,304 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-11 16:33:03,304 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-11 16:33:03,305 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-11 16:33:03,307 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-11 16:33:03,307 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-11 16:33:03,343 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-11 16:33:03,344 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-11 16:33:03,345 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-11 16:33:03,345 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-11 16:33:03,346 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-11 16:33:03,347 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-11 16:33:03,347 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-11 16:33:03,348 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-11 16:33:03,349 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-11 16:33:03,349 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-11 16:33:03,350 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-11 16:33:03,350 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-11 16:33:03,351 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-11 16:33:03,352 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-11 16:33:03,353 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-11 16:33:03,353 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-11 16:33:03,354 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-11 16:33:03,354 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-11 16:33:03,355 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-11 16:33:03,356 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-11 16:33:03,393 - INFO : Skipping Document: 166403. Output JSON already exists.
# 2026-01-11 16:33:03,393 - INFO : Skipping Document: 127663. Output JSON already exists.
# 2026-01-11 16:33:03,394 - INFO : Skipping Document: 166549. Output JSON already exists.
# 2026-01-11 16:33:03,395 - INFO : Skipping Document: 166548. Output JSON already exists.
# 2026-01-11 16:33:03,397 - INFO : Skipping Document: 300825. Output JSON already exists.
# 2026-01-11 16:33:03,398 - INFO : Skipping Document: 338740. Output JSON already exists.
# 2026-01-11 16:33:03,398 - INFO : Skipping Document: 166479. Output JSON already exists.
# 2026-01-11 16:33:03,399 - INFO : Skipping Document: 166519. Output JSON already exists.
# 2026-01-11 16:33:03,399 - INFO : Skipping Document: 166478. Output JSON already exists.
# 2026-01-11 16:33:03,400 - INFO : Skipping Document: 338741. Output JSON already exists.
# 2026-01-11 16:33:03,400 - INFO : Skipping Document: 166520. Output JSON already exists.
# 2026-01-11 16:33:03,401 - INFO : Skipping Document: 166480. Output JSON already exists.
# 2026-01-11 16:33:03,401 - INFO : Skipping Document: 305969. Output JSON already exists.
# 2026-01-11 16:33:03,402 - INFO : Skipping Document: 177003. Output JSON already exists.
# 2026-01-11 16:33:03,402 - INFO : Skipping Document: 131384. Output JSON already exists.
# 2026-01-11 16:33:03,402 - INFO : Skipping Document: 131385. Output JSON already exists.
# 2026-01-11 16:33:03,403 - INFO : Skipping Document: 306552. Output JSON already exists.
# 2026-01-11 16:33:03,403 - INFO : Skipping Document: 131386. Output JSON already exists.
# 2026-01-11 16:33:03,403 - INFO : Skipping Document: 131382. Output JSON already exists.
# 2026-01-11 16:33:03,404 - INFO : Skipping Document: 131383. Output JSON already exists.
# 2026-01-11 16:33:03,567 - INFO : Saved table content to: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/thesis/figures/example_table.tex
