# %%
from lib.evaluation.parsing.time_statistics import get_time_stats
from lib.utils.export_to_latex import export_table_to_latex

df = get_time_stats()
export_table_to_latex(df, "time_per_page", switch_highlighting=True)
# Out:
# 2026-01-30 15:37:37,946 - DEBUG : Successfully initialized Logging.
# 2026-01-30 15:37:38,972 - INFO : Saved table content to: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/thesis/figures/tables/time_per_page.tex
