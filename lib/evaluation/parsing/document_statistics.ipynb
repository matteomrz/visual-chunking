# %%
from lib.evaluation.parsing.statistics import get_time_stats

get_time_stats()
# Out:
#                    Parsing                                   Transformation  \
#                       mean        std        min         max           mean
# Method
# docling           2.114572   1.314686   0.374339   17.083177       0.001711
# docling_granite  16.896811  70.853749   1.642606  910.910747       0.001514
# document_ai       1.744015        NaN   1.744015    1.744015       1.838333
# gemini           20.256367  10.021461   4.120727   46.301485       0.000408
# llamaparse       37.095564  41.682245   3.503820  909.398152       0.735388
# mineru_pipeline  26.594918  38.099000   4.413221  472.862703       0.001393
# mineru_vlm       52.643476  48.026343  17.532970  555.625243       0.000629
# unstructured_io   4.974504   5.528471   1.793263  135.946873       0.000772
# vlm               0.000014   0.000011   0.000001    0.000023       0.000053
#
#
#                       std       min       max
# Method
# docling          0.002376  0.000403  0.052035
# ...
