# %%
from lib.evaluation.parsing.omni_doc_bench.omni_doc_bench import (
    create_result_table,
    get_omni_doc_dt_path,
    prepare_omni_doc_bench
)
from lib.utils.export_to_latex import export_table_to_latex

prepare_omni_doc_bench(exist_ok=True)
# Out:
# 2026-02-08 12:19:57,995 - INFO : OmniDocBench.json already exists at: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/guidelines/omni_doc_bench/OmniDocBench.json.Skipping download from Huggingface.
# Fetching 0 files: 0it [00:00, ?it/s]
# 2026-02-08 12:19:58,769 - INFO : Downloaded 0 images from the OmniDocBench benchmark.
# 2026-02-08 12:19:58,779 - INFO : Finished setup for OmniDocBench. For usage check the README.md.

# %%
from lib.parsing.methods.parsers import Parsers


def get_command_for_parser(parser: Parsers):
    config_path = get_omni_doc_dt_path(parser)
    print(f"python pdf_validation.py --config {config_path}\n")

# %%
get_command_for_parser(Parsers.DOCLING)
# Out:
# python pdf_validation.py --config /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/omni_doc_bench/docling.yaml

# %%
df = create_result_table()
export_table_to_latex(df, "omni_doc_bench")
# Out:
# 2026-02-08 12:20:13,694 - WARNING : Missing OmniDocBench result for llamaparse at: /Users/matteo/Uni/7.Semester/thesis/omni_doc/OmniDocBench/result/llamaparse_quick_match_metric_result.json
# 2026-02-08 12:20:13,951 - INFO : Saved table content to: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/thesis/figures/tables/omni_doc_bench.tex

# %%
df
# Out:
#                  text_block_Edit_dist  table_TEDS  table_TEDS_structure_only  \
# unstructured_io                 0.084      64.360                     82.087
# docling                         0.078      66.329                     85.259
# docling_granite                 0.136      64.211                     70.042
# mineru_pipeline                 0.044      80.216                     90.132
# mineru_vlm                      0.025      86.094                     92.820
# gemini                          0.045      65.368                     72.608
# document_ai                     0.048       0.000                      0.000
#
#                  reading_order_Edit_dist    overall
# unstructured_io                    0.116  81.453333
# docling                            0.079  83.543000
# docling_granite                    0.089  80.570333
# mineru_pipeline                    0.039  90.638667
# mineru_vlm                         0.006  94.331333
# gemini                             0.041  85.589333
# document_ai                        0.038  63.800000
