# %%
from lib.evaluation.parsing.omni_doc_bench.omni_doc_bench import get_omni_doc_dt_path, \
    prepare_omni_doc_bench
from lib.parsing.methods.parsers import Parsers

prepare_omni_doc_bench(exist_ok=True)
# Out:
# 2026-02-03 23:06:24,296 - DEBUG : Successfully initialized Logging.
# 2026-02-03 23:06:24,472 - INFO : OmniDocBench.json already exists at: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/guidelines/omni_doc_bench/OmniDocBench.json.Skipping download from Huggingface.
# Fetching 0 files: 0it [00:00, ?it/s]
# 2026-02-03 23:06:25,378 - INFO : Downloaded 0 images from the OmniDocBench benchmark.
# 2026-02-03 23:06:25,380 - INFO : Skipping existing PDF for: scihub_gbe%2Fevaa098.pdf_0
# 2026-02-03 23:06:25,380 - INFO : Skipping existing PDF for: scihub_j.cbpb.2019.110324.pdf_6
# 2026-02-03 23:06:25,381 - INFO : Skipping existing PDF for: docstructbench_llm-raw-scihub-o.O-s0362-546x%2897%2900070-9.pdf_7
# 2026-02-03 23:06:25,381 - INFO : Skipping existing PDF for: scihub_j.physe.2007.10.027.pdf_0
# 2026-02-03 23:06:25,381 - INFO : Skipping existing PDF for: docstructbench_llm-raw-scihub-o.O-ajhb.10190.pdf_5
# ...

# %%
for parser in Parsers:
    config_path = get_omni_doc_dt_path(parser)
    print(f"{parser.value}: python pdf_validation.py --config {config_path}\n")
# Out:
# llamaparse: python pdf_validation.py --config /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/omni_doc_bench/llamaparse.yaml
#
# unstructured_io: python pdf_validation.py --config /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/omni_doc_bench/unstructured_io.yaml
#
# docling: python pdf_validation.py --config /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/omni_doc_bench/docling.yaml
#
# docling_granite: python pdf_validation.py --config /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/omni_doc_bench/docling_granite.yaml
#
# mineru_pipeline: python pdf_validation.py --config /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/omni_doc_bench/mineru_pipeline.yaml
#
# mineru_vlm: python pdf_validation.py --config /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/omni_doc_bench/mineru_vlm.yaml
#
# ...
