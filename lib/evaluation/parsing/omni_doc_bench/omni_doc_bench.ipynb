# %%
from lib.evaluation.parsing.omni_doc_bench.omni_doc_bench import (
    create_result_table,
    get_omni_doc_dt_path,
    prepare_omni_doc_bench
)
from lib.utils.export_to_latex import export_table_to_latex

prepare_omni_doc_bench(exist_ok=False)
# Out:
# 2026-02-04 23:24:14,320 - DEBUG : Successfully initialized Logging.
# Fetching 129 files:   0%|          | 0/129 [00:00<?, ?it/s]
# 2026-02-04 23:24:16,005 - INFO : Downloaded 129 images from the OmniDocBench benchmark.
# 2026-02-04 23:24:16,021 - INFO : Successfully created PDF for: scihub_gbe%2Fevaa098.pdf_0
# 2026-02-04 23:24:16,026 - INFO : Successfully created PDF for: scihub_j.cbpb.2019.110324.pdf_6
# 2026-02-04 23:24:16,032 - INFO : Successfully created PDF for: docstructbench_llm-raw-scihub-o.O-s0362-546x%2897%2900070-9.pdf_7
# 2026-02-04 23:24:16,037 - INFO : Successfully created PDF for: scihub_j.physe.2007.10.027.pdf_0
# 2026-02-04 23:24:16,046 - INFO : Successfully created PDF for: docstructbench_llm-raw-scihub-o.O-ajhb.10190.pdf_5
# 2026-02-04 23:24:16,050 - INFO : Successfully created PDF for: docstructbench_llm-raw-scihub-o.O-hup.777.pdf_8
# 2026-02-04 23:24:16,054 - INFO : Successfully created PDF for: scihub_s00381-021-05138-3.pdf_3
# ...

# %%
from lib.parsing.methods.parsers import Parsers


def get_command_for_parser(parser: Parsers):
    config_path = get_omni_doc_dt_path(parser)
    print(f"python pdf_validation.py --config {config_path}\n")

# %%
get_command_for_parser(Parsers.DOCLING)
# Out:
# python pdf_validation.py --config /Users/matteo/Uni/7.Semester/thesis/visual-chunking/data/configs/omni_doc_bench/docling.yaml

# %%
df = create_result_table()
export_table_to_latex(df, "omni_doc_bench")
# Out:
# 2026-02-04 23:24:16,890 - WARNING : Missing OmniDocBench result for llamaparse at: /Users/matteo/Uni/7.Semester/thesis/omni_doc/OmniDocBench/result/llamaparse_quick_match_metric_result.json
# 2026-02-04 23:24:17,152 - INFO : Saved table content to: /Users/matteo/Uni/7.Semester/thesis/visual-chunking/thesis/figures/tables/omni_doc_bench.tex

# %%
df
# Out:
#                  text_block_Edit_dist  display_formula_CDM  table_TEDS  \
# unstructured_io                 0.085                  0.0       0.000
# docling                         0.078                  0.0      66.329
# docling_granite                 0.136                  0.0      64.211
# mineru_pipeline                 0.044                  0.0      80.216
# mineru_vlm                      0.025                  0.0      86.094
# gemini                          0.045                  0.0      65.368
# document_ai                     0.048                  0.0       0.000
#
#                  table_TEDS_structure_only  reading_order_Edit_dist    overall
# unstructured_io                      0.000                    0.116  30.500000
# docling                             85.259                    0.079  52.843000
# docling_granite                     70.042                    0.089  50.203667
# mineru_pipeline                     90.132                    0.039  58.605333
# ...
